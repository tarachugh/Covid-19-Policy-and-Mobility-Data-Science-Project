# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler





data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794395  United States          NaN  2020-02-15
# 1794396  United States          NaN  2020-02-16
# 1794397  United States          NaN  2020-02-17
# 1794398  United States          NaN  2020-02-18
# 1794399  United States          NaN  2020-02-19
# ...                ...          ...         ...
# 2332432  United States      Wyoming  2020-08-31
# 2332433  United States      Wyoming  2020-09-01
# 2332434  United States      Wyoming  2020-09-02
# 2332435  United States      Wyoming  2020-09-03
# 2332436  United States      Wyoming  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
unique=data.sub_region_1.unique()

# %%
count=0

for index, row in data.iterrows():
    if row["sub_region_1"]=="Alabama":
        count+=1
print(count)
# Out:
# 3209

# %%
count=0

for index, row in data.iterrows():
    if row["sub_region_1"]=="Wyoming":
        count+=1
print(count)
# Out:
# 836

# %%
count=0

for index, row in data.iterrows():
    if row["sub_region_1"]=="Connecticut":
        count+=1
print(count)
# Out:
# 1449

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794598  United States      Alabama  2020-02-15
# 1794599  United States      Alabama  2020-02-16
# 1794600  United States      Alabama  2020-02-17
# 1794601  United States      Alabama  2020-02-18
# 1794602  United States      Alabama  2020-02-19
# ...                ...          ...         ...
# 2331610  United States      Wyoming  2020-05-07
# 2331611  United States      Wyoming  2020-05-08
# 2331616  United States      Wyoming  2020-05-13
# 2331618  United States      Wyoming  2020-05-15
# 2331623  United States      Wyoming  2020-05-20
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794598                                           0.989149
# 1794599                                           0.732568
# 1794600                                           0.886517
# 1794601                                           0.527303
# 1794602                                           0.937833
# ...                                                    ...
# 2331610                                           0.116773
# 2331611                                           0.219405
# 2331616                                           0.373354
# 2331618                                           0.219405
# 2331623                                           0.989149
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794598                                           0.140288
# 1794599                                          -0.163242
# 1794600                                          -0.011477
# 1794601                                          -0.239124
# 1794602                                           0.064405
# ...                                                    ...
# 2331610                                           0.595582
# 2331611                                           1.278523
# 2331616                                           0.671464
# 2331618                                           0.823229
# 2331623                                           0.747346
#
#          transit_stations_percent_change_from_baseline  \
# 1794598                                       0.802510
# 1794599                                       0.645974
# 1794600                                       0.802510
# 1794601                                       0.489437
# 1794602                                       0.685108
# ...                                                ...
# 2331610                                       1.193852
# 2331611                                       2.407013
# 2331616                                       1.546060
# 2331618                                       2.602684
# 2331623                                       1.741731
#
#          workplaces_percent_change_from_baseline  \
# 1794598                                 1.783445
# 1794599                                 1.606113
# 1794600                                 0.660343
# 1794601                                 1.724335
# 1794602                                 1.724335
# ...                                          ...
# 2331610                                 0.010126
# 2331611                                -0.048985
# 2331616                                 0.069237
# 2331618                                 0.128347
# 2331623                                 0.128347
#
#          residential_percent_change_from_baseline
# 1794598                                 -1.443475
# 1794599                                 -1.156872
# 1794600                                 -0.726968
# 1794601                                 -1.013571
# 1794602                                 -1.300174
# ...                                           ...
# 2331610                                 -0.010461
# 2331611                                 -0.010461
# 2331616                                 -0.010461
# 2331618                                 -0.153762
# 2331623                                 -0.440365
#
# [156604 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.72008335 0.13991325 0.07695239 0.0456524 ]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#             PC 1      PC 2      PC 3      PC 4
# 0       2.354391 -1.143334  0.099191  0.097233
# 1       1.827137 -1.202345  0.203013  0.095342
# 2       1.404286 -0.310379  0.440112  0.362566
# 3       1.615274 -1.339801  0.121944 -0.034157
# 4       2.153825 -1.136191  0.070387  0.131507
# ...          ...       ...       ...       ...
# 156599  0.823165  0.676877  0.662480 -0.467199
# 156600  1.647464  1.454389  1.307348 -0.969484
# 156601  1.154456  0.829655  0.891517 -0.393623
# 156602  1.696530  1.056413  1.665581 -0.877865
# 156603  1.793378  0.840676  0.924706  0.022434
#
# [156604 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline  0.473530  0.209291
# grocery_and_pharmacy_percent_change_from_baseline   0.402169  0.622555
# transit_stations_percent_change_from_baseline       0.434605  0.244480
# workplaces_percent_change_from_baseline             0.443293 -0.579767
# residential_percent_change_from_baseline           -0.478162  0.415598
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.048658  0.831408
# grocery_and_pharmacy_percent_change_from_baseline  -0.528295 -0.414086
# transit_stations_percent_change_from_baseline       0.825536 -0.263928
# workplaces_percent_change_from_baseline            -0.154791 -0.260003
# residential_percent_change_from_baseline            0.114311 -0.005850

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: retail, grocery, transit, workplaces")
print("Greatest contributors to PC2: grocery, residential")
print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: retail")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: retail, grocery, transit, workplaces
# Greatest contributors to PC2: grocery, residential
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: retail

# %%
# find OPTIMAL value for kmeans
from sklearn.cluster import KMeans
data_kmeans = pd.DataFrame(pca_data)
Sum_of_squared_distances = []
K = range(1,7)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(pca_data)
    Sum_of_squared_distances.append(km.inertia_)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f429380dc108> in <module>
#       6 for k in K:
#       7     km = KMeans(n_clusters=k)
# ----> 8     km = km.fit(pca_data)
#       9     Sum_of_squared_distances.append(km.inertia_)
#      10 plt.plot(K, Sum_of_squared_distances, 'bx-')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1066         for seed in seeds:
#    1067             # run a k-means once
# -> 1068             labels, inertia, centers, n_iter_ = kmeans_single(
#    1069                 X, sample_weight, self.n_clusters, max_iter=self.max_iter,
#    1070                 init=init, verbose=self.verbose, tol=self._tol,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, n_threads)
#     385
#     386     # init
# --> 387     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
#     388                               x_squared_norms=x_squared_norms)
#     389
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in _init_centroids(X, n_clusters, init, random_state, x_squared_norms, init_size)
#     723
#     724     if isinstance(init, str) and init == 'k-means++':
# --> 725         centers = _k_init(X, n_clusters, random_state=random_state,
#     726                           x_squared_norms=x_squared_norms)
#     727     elif isinstance(init, str) and init == 'random':
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in _k_init(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     118
#     119         # Compute distances to center candidates
# --> 120         distance_to_candidates = euclidean_distances(
#     121             X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True)
#     122
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     308     else:
#     309         # if dtype is already float64, no need to chunk and upcast
# --> 310         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     311         distances += XX
#     312         distances += YY
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=5)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#             PC 1      PC 2      PC 3      PC 4  Cluster
# 0       2.354391 -1.143334  0.099191  0.097233        1
# 1       1.827137 -1.202345  0.203013  0.095342        1
# 2       1.404286 -0.310379  0.440112  0.362566        1
# 3       1.615274 -1.339801  0.121944 -0.034157        1
# 4       2.153825 -1.136191  0.070387  0.131507        1
# ...          ...       ...       ...       ...      ...
# 156599  0.823165  0.676877  0.662480 -0.467199        0
# 156600  1.647464  1.454389  1.307348 -0.969484        4
# 156601  1.154456  0.829655  0.891517 -0.393623        4
# 156602  1.696530  1.056413  1.665581 -0.877865        4
# 156603  1.793378  0.840676  0.924706  0.022434        4
#
# [156604 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#             PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0       2.354391 -1.143334  0.099191  0.097233        1  Alabama
# 1       1.827137 -1.202345  0.203013  0.095342        1  Alabama
# 2       1.404286 -0.310379  0.440112  0.362566        1  Alabama
# 3       1.615274 -1.339801  0.121944 -0.034157        1  Alabama
# 4       2.153825 -1.136191  0.070387  0.131507        1  Alabama
# ...          ...       ...       ...       ...      ...      ...
# 156599  0.823165  0.676877  0.662480 -0.467199        0  Wyoming
# 156600  1.647464  1.454389  1.307348 -0.969484        4  Wyoming
# 156601  1.154456  0.829655  0.891517 -0.393623        4  Wyoming
# 156602  1.696530  1.056413  1.665581 -0.877865        4  Wyoming
# 156603  1.793378  0.840676  0.924706  0.022434        4  Wyoming
#
# [156604 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([1, 4, 0, 3, 2], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 1492, 'Alaska': 214, 'Arizona': 485, 'Arkansas': 1125, 'California': 1865, 'Colorado': 725, 'Connecticut': 406, 'Delaware': 186, 'District of Columbia': 2, 'Florida': 1405, 'Georgia': 2089, 'Hawaii': 14, 'Idaho': 289, 'Illinois': 1592, 'Indiana': 1549, 'Iowa': 490, 'Kansas': 725, 'Kentucky': 1191, 'Louisiana': 1528, 'Maine': 240, 'Maryland': 486, 'Massachusetts': 460, 'Michigan': 953, 'Minnesota': 604, 'Mississippi': 1094, 'Missouri': 1068, 'Montana': 201, 'Nebraska': 466, 'Nevada': 178, 'New Hampshire': 315, 'New Jersey': 672, 'New Mexico': 708, 'New York': 1366, 'North Carolina': 2401, 'North Dakota': 320, 'Ohio': 2074, 'Oklahoma': 911, 'Oregon': 811, 'Pennsylvania': 1627, 'Rhode Island': 148, 'South Carolina': 1737, 'South Dakota': 95, 'Tennessee': 1944, 'Texas': 4097, 'Utah': 547, 'Vermont': 199, 'Virginia': 1685, 'Washington': 1265, 'West Virginia': 477, 'Wisconsin': 950, 'Wyoming': 164}, {'Alabama': 603, 'Alaska': 173, 'Arizona': 323, 'Arkansas': 459, 'California': 1158, 'Colorado': 556, 'Connecticut': 314, 'Delaware': 139, 'District of Columbia': 26, 'Florida': 1180, 'Georgia': 948, 'Hawaii': 135, 'Idaho': 309, 'Illinois': 1032, 'Indiana': 1213, 'Iowa': 415, 'Kansas': 521, 'Kentucky': 559, 'Louisiana': 595, 'Maine': 200, 'Maryland': 486, 'Massachusetts': 396, 'Michigan': 808, 'Minnesota': 430, 'Mississippi': 374, 'Missouri': 789, 'Montana': 240, 'Nebraska': 325, 'Nevada': 114, 'New Hampshire': 203, 'New Jersey': 665, 'New Mexico': 272, 'New York': 1094, 'North Carolina': 1038, 'North Dakota': 285, 'Ohio': 1539, 'Oklahoma': 512, 'Oregon': 527, 'Pennsylvania': 1291, 'Rhode Island': 133, 'South Carolina': 746, 'South Dakota': 103, 'Tennessee': 1095, 'Texas': 1803, 'Utah': 343, 'Vermont': 93, 'Virginia': 1038, 'Washington': 707, 'West Virginia': 242, 'Wisconsin': 759, 'Wyoming': 201}, {'Alabama': 77, 'Alaska': 63, 'Arizona': 228, 'Arkansas': 35, 'California': 1911, 'Colorado': 473, 'Connecticut': 298, 'Delaware': 127, 'District of Columbia': 148, 'Florida': 1219, 'Georgia': 396, 'Hawaii': 631, 'Idaho': 36, 'Illinois': 490, 'Indiana': 336, 'Iowa': 96, 'Kansas': 97, 'Kentucky': 114, 'Louisiana': 314, 'Maine': 141, 'Maryland': 698, 'Massachusetts': 772, 'Michigan': 849, 'Minnesota': 345, 'Mississippi': 51, 'Missouri': 226, 'Montana': 92, 'Nebraska': 33, 'Nevada': 134, 'New Hampshire': 176, 'New Jersey': 1192, 'New Mexico': 94, 'New York': 1633, 'North Carolina': 430, 'North Dakota': 60, 'Ohio': 489, 'Oklahoma': 27, 'Oregon': 290, 'Pennsylvania': 1143, 'Rhode Island': 195, 'South Carolina': 105, 'South Dakota': 14, 'Tennessee': 147, 'Texas': 925, 'Utah': 71, 'Vermont': 183, 'Virginia': 910, 'Washington': 464, 'West Virginia': 99, 'Wisconsin': 451, 'Wyoming': 12}, {'Alabama': 592, 'Alaska': 80, 'Arizona': 945, 'Arkansas': 359, 'California': 2869, 'Colorado': 793, 'Connecticut': 383, 'Delaware': 209, 'District of Columbia': 27, 'Florida': 3408, 'Georgia': 1525, 'Hawaii': 172, 'Idaho': 186, 'Illinois': 1181, 'Indiana': 913, 'Iowa': 396, 'Kansas': 331, 'Kentucky': 641, 'Louisiana': 927, 'Maine': 189, 'Maryland': 952, 'Massachusetts': 738, 'Michigan': 777, 'Minnesota': 669, 'Mississippi': 394, 'Missouri': 705, 'Montana': 193, 'Nebraska': 292, 'Nevada': 320, 'New Hampshire': 175, 'New Jersey': 1273, 'New Mexico': 780, 'New York': 1877, 'North Carolina': 1525, 'North Dakota': 206, 'Ohio': 1349, 'Oklahoma': 297, 'Oregon': 763, 'Pennsylvania': 1576, 'Rhode Island': 283, 'South Carolina': 755, 'South Dakota': 113, 'Tennessee': 954, 'Texas': 3520, 'Utah': 404, 'Vermont': 196, 'Virginia': 1743, 'Washington': 1023, 'West Virginia': 258, 'Wisconsin': 716, 'Wyoming': 143}, {'Alabama': 445, 'Alaska': 82, 'Arizona': 336, 'Arkansas': 389, 'California': 308, 'Colorado': 286, 'Connecticut': 48, 'Delaware': 99, 'Florida': 329, 'Georgia': 425, 'Hawaii': 1, 'Idaho': 428, 'Illinois': 559, 'Indiana': 1253, 'Iowa': 618, 'Kansas': 287, 'Kentucky': 296, 'Louisiana': 406, 'Maine': 224, 'Maryland': 26, 'Massachusetts': 142, 'Michigan': 470, 'Mi ...

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 1492, 1: 603, 2: 77, 3: 592, 4: 445}
# {0: 214, 1: 173, 2: 63, 3: 80, 4: 82}
# {0: 485, 1: 323, 2: 228, 3: 945, 4: 336}
# {0: 1125, 1: 459, 2: 35, 3: 359, 4: 389}
# {0: 1865, 1: 1158, 2: 1911, 3: 2869, 4: 308}
# {0: 725, 1: 556, 2: 473, 3: 793, 4: 286}
# {0: 406, 1: 314, 2: 298, 3: 383, 4: 48}
# {0: 186, 1: 139, 2: 127, 3: 209, 4: 99}
# {0: 2, 1: 26, 2: 148, 3: 27}
# {0: 1405, 1: 1180, 2: 1219, 3: 3408, 4: 329}
# {0: 2089, 1: 948, 2: 396, 3: 1525, 4: 425}
# {0: 14, 1: 135, 2: 631, 3: 172, 4: 1}
# {0: 289, 1: 309, 2: 36, 3: 186, 4: 428}
# {0: 1592, 1: 1032, 2: 490, 3: 1181, 4: 559}
# {0: 1549, 1: 1213, 2: 336, 3: 913, 4: 1253}
# {0: 490, 1: 415, 2: 96, 3: 396, 4: 618}
# {0: 725, 1: 521, 2: 97, 3: 331, 4: 287}
# {0: 1191, 1: 559, 2: 114, 3: 641, 4: 296}
# {0: 1528, 1: 595, 2: 314, 3: 927, 4: 406}
# {0: 240, 1: 200, 2: 141, 3: 189, 4: 224}
# {0: 486, 1: 486, 2: 698, 3: 952, 4: 26}
# {0: 460, 1: 396, 2: 772, 3: 738, 4: 142}
# {0: 953, 1: 808, 2: 849, 3: 777, 4: 470}
# {0: 604, 1: 430, 2: 345, 3: 669, 4: 104}
# {0: 1094, 1: 374, 2: 51, 3: 394, 4: 217}
# {0: 1068, 1: 789, 2: 226, 3: 705, 4: 793}
# {0: 201, 1: 240, 2: 92, 3: 193, 4: 513}
# {0: 466, 1: 325, 2: 33, 3: 292, 4: 235}
# {0: 178, 1: 114, 2: 134, 3: 320, 4: 195}
# {0: 315, 1: 203, 2: 176, 3: 175, 4: 104}
# {0: 672, 1: 665, 2: 1192, 3: 1273, 4: 166}
# {0: 708, 1: 272, 2: 94, 3: 780, 4: 196}
# {0: 1366, 1: 1094, 2: 1633, 3: 1877, 4: 400}
# {0: 2401, 1: 1038, 2: 430, 3: 1525, 4: 358}
# {0: 320, 1: 285, 2: 60, 3: 206, 4: 149}
# {0: 2074, 1: 1539, 2: 489, 3: 1349, 4: 1414}
# {0: 911, 1: 512, 2: 27, 3: 297, 4: 722}
# {0: 811, 1: 527, 2: 290, 3: 763, 4: 562}
# {0: 1627, 1: 1291, 2: 1143, 3: 1576, 4: 646}
# {0: 148, 1: 133, 2: 195, 3: 283, 4: 52}
# {0: 1737, 1: 746, 2: 105, 3: 755, 4: 375}
# {0: 95, 1: 103, 2: 14, 3: 113, 4: 294}
# {0: 1944, 1: 1095, 2: 147, 3: 954, 4: 666}
# {0: 4097, 1: 1803, 2: 925, 3: 3520, 4: 857}
# {0: 547, 1: 343, 2: 71, 3: 404, 4: 514}
# {0: 199, 1: 93, 2: 183, 3: 196, 4: 23}
# {0: 1685, 1: 1038, 2: 910, 3: 1743, 4: 308}
# {0: 1265, 1: 707, 2: 464, 3: 1023, 4: 537}
# {0: 477, 1: 242, 2: 99, 3: 258, 4: 188}
# {0: 950, 1: 759, 2: 451, 3: 716, 4: 464}
# {0: 164, 1: 201, 2: 12, 3: 143, 4: 316}
# {'Alabama': 0, 'Alaska': 0, 'Arizona': 3, 'Arkansas': 0, 'California': 3, 'Colorado': 3, 'Connecticut': 0, 'Delaware': 3, 'District of Columbia': 2, 'Florida': 3, 'Georgia': 0, 'Hawaii': 2, 'Idaho': 4, 'Illinois': 0, 'Indiana': 0, 'Iowa': 4, 'Kansas': 0, 'Kentucky': 0, 'Louisiana': 0, 'Maine': 0, 'Maryland': 3, 'Massachusetts': 2, 'Michigan': 0, 'Minnesota': 3, 'Mississippi': 0, 'Missouri': 0, 'Montana': 4, 'Nebraska': 0, 'Nevada': 3, 'New Hampshire': 0, 'New Jersey': 3, 'New Mexico': 3, 'New York': 3, 'North Carolina': 0, 'North Dakota': 0, 'Ohio': 0, 'Oklahoma': 0, 'Oregon': 0, 'Pennsylvania': 0, 'Rhode Island': 3, 'South Carolina': 0, 'South Dakota': 4, 'Tennessee': 0, 'Texas': 0, 'Utah': 0, 'Vermont': 0, 'Virginia': 3, 'Washington': 0, 'West Virginia': 0, 'Wisconsin': 0, 'Wyoming': 4}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: [], 2: ['District of Columbia', 'Hawaii', 'Massachusetts'], 3: ['Arizona', 'California', 'Colorado', 'Delaware', 'Florida', 'Maryland', 'Minnesota', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'Rhode Island', 'Virginia'], 4: ['Idaho', 'Iowa', 'Montana', 'South Dakota', 'Wyoming'], 0: ['Alabama', 'Alaska', 'Arkansas', 'Connecticut', 'Georgia', 'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Michigan', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Washington', 'West Virginia', 'Wisconsin']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%100==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"]+1,"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0     2.354391 -1.143334  0.099191  1.097233       1  Alabama
# 1    -1.729728  1.719860  0.457237  1.366056       3  Alabama
# 2     0.806779  0.160688  0.244880  1.379074       0  Alabama
# 3     1.609379  1.262085 -0.582437  0.837796       4  Alabama
# 4     1.980533  0.283411  0.042739  0.575715       4  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1562 -1.359212  0.538214  0.253513  0.735028       3  Wyoming
# 1563  1.226888  0.753202  0.668202  0.675220       4  Wyoming
# 1564 -0.970658  0.399314 -0.437251  0.867314       3  Wyoming
# 1565  1.342484  0.760758 -0.061508  0.813799       4  Wyoming
# 1566  1.647464  1.454389  1.307348  0.030516       4  Wyoming
#
# [1567 rows x 6 columns]>

# %%
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0     2.354391 -1.143334  0.099191  1.097233       1  Alabama
# 1    -1.729728  1.719860  0.457237  1.366056       3  Alabama
# 2     0.806779  0.160688  0.244880  1.379074       0  Alabama
# 3     1.609379  1.262085 -0.582437  0.837796       4  Alabama
# 4     1.980533  0.283411  0.042739  0.575715       4  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1562 -1.359212  0.538214  0.253513  0.735028       3  Wyoming
# 1563  1.226888  0.753202  0.668202  0.675220       4  Wyoming
# 1564 -0.970658  0.399314 -0.437251  0.867314       3  Wyoming
# 1565  1.342484  0.760758 -0.061508  0.813799       4  Wyoming
# 1566  1.647464  1.454389  1.307348  0.030516       4  Wyoming
#
# [1567 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([[], ['District of Columbia', 'Hawaii', 'Massachusetts'], ['Arizona', 'California', 'Colorado', 'Delaware', 'Florida', 'Maryland', 'Minnesota', 'Nevada', 'New Jersey', 'New Mexico', 'New York', 'Rhode Island', 'Virginia'], ['Idaho', 'Iowa', 'Montana', 'South Dakota', 'Wyoming'], ['Alabama', 'Alaska', 'Arkansas', 'Connecticut', 'Georgia', 'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Michigan', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Washington', 'West Virginia', 'Wisconsin']])

# %%
vals=list(clusters_and_their_states.values())
keys=list(clusters_and_their_states.keys())
for index, row in pca_2.iterrows():
    for i in range(len(vals)):
        if row["State"] in vals[i]:
            pca_2.at[index, "Cluster"]= keys[i]
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0     2.354391 -1.143334  0.099191  1.097233       0  Alabama
# 1    -1.729728  1.719860  0.457237  1.366056       0  Alabama
# 2     0.806779  0.160688  0.244880  1.379074       0  Alabama
# 3     1.609379  1.262085 -0.582437  0.837796       0  Alabama
# 4     1.980533  0.283411  0.042739  0.575715       0  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1562 -1.359212  0.538214  0.253513  0.735028       4  Wyoming
# 1563  1.226888  0.753202  0.668202  0.675220       4  Wyoming
# 1564 -0.970658  0.399314 -0.437251  0.867314       4  Wyoming
# 1565  1.342484  0.760758 -0.061508  0.813799       4  Wyoming
# 1566  1.647464  1.454389  1.307348  0.030516       4  Wyoming
#
# [1567 rows x 6 columns]

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 2']+8)*4

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 4"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers')

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("Google Mobility KMeans.html")
                   )
# Out:
# 'Google Mobility KMeans.html'
