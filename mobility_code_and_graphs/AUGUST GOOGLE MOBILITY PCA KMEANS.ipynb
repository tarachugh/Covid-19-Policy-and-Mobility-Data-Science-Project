# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-08")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794563                  US  United States          NaN            NaN
# 1794564                  US  United States          NaN            NaN
# 1794565                  US  United States          NaN            NaN
# 1794566                  US  United States          NaN            NaN
# 1794567                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332428                  US  United States      Wyoming  Weston County
# 2332429                  US  United States      Wyoming  Weston County
# 2332430                  US  United States      Wyoming  Weston County
# 2332431                  US  United States      Wyoming  Weston County
# 2332432                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794563        NaN             NaN               NaN  2020-08-01
# 1794564        NaN             NaN               NaN  2020-08-02
# 1794565        NaN             NaN               NaN  2020-08-03
# 1794566        NaN             NaN               NaN  2020-08-04
# 1794567        NaN             NaN               NaN  2020-08-05
# ...            ...             ...               ...         ...
# 2332428        NaN             NaN           56045.0  2020-08-25
# 2332429        NaN             NaN           56045.0  2020-08-26
# 2332430        NaN             NaN           56045.0  2020-08-27
# 2332431        NaN             NaN           56045.0  2020-08-28
# 2332432        NaN             NaN           56045.0  2020-08-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794563                                              -17.0
# 1794564                                              -16.0
# 1794565                                              -12.0
# 1794566                                              -13.0
# 1794567                                              -11.0
# ...                                                    ...
# 2332428                                                NaN
# 2332429                                                NaN
# 2332430                                                NaN
# 2332431                                                NaN
# 2332432                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794563                                                0.0
# 1794564                                               -4.0
# 1794565                                               -1.0
# 1794566                                               -3.0
# 1794567                                               -2.0
# ...                                                    ...
# 2332428                                                NaN
# 2332429                                                NaN
# 2332430                                                NaN
# 2332431                                                NaN
# 2332432                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794563                                69.0
# 1794564                                52.0
# 1794565                                47.0
# 1794566                                48.0
# 1794567                                61.0
# ...                                     ...
# 2332428                                 NaN
# 2332429                                 NaN
# 2332430                                 NaN
# 2332431                                 NaN
# 2332432                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794563                                          -20.0
# 1794564                                          -24.0
# 1794565                                          -31.0
# 1794566                                          -33.0
# 1794567                                          -30.0
# ...                                                ...
# 2332428                                            NaN
# 2332429                                            NaN
# 2332430                                            NaN
# 2332431                                            NaN
# 2332432                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794563                                    -14.0
# 1794564                                    -17.0
# 1794565                                    -38.0
# 1794566                                    -39.0
# 1794567                                    -37.0
# ...                                          ...
# 2332428                                    -23.0
# 2332429                                    -22.0
# 2332430                                    -16.0
# 2332431                                    -20.0
# 2332432                                    -21.0
#
#          residential_percent_change_from_baseline
# 1794563                                       4.0
# 1794564                                       3.0
# 1794565                                      10.0
# 1794566                                      11.0
# 1794567                                      10.0
# ...                                           ...
# 2332428                                       NaN
# 2332429                                       NaN
# 2332430                                       NaN
# 2332431                                       NaN
# 2332432                                       NaN
#
# [80145 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794563  United States          NaN  2020-08-01
# 1794564  United States          NaN  2020-08-02
# 1794565  United States          NaN  2020-08-03
# 1794566  United States          NaN  2020-08-04
# 1794567  United States          NaN  2020-08-05
# ...                ...          ...         ...
# 2332428  United States      Wyoming  2020-08-25
# 2332429  United States      Wyoming  2020-08-26
# 2332430  United States      Wyoming  2020-08-27
# 2332431  United States      Wyoming  2020-08-28
# 2332432  United States      Wyoming  2020-08-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794563                                              -17.0
# 1794564                                              -16.0
# 1794565                                              -12.0
# 1794566                                              -13.0
# 1794567                                              -11.0
# ...                                                    ...
# 2332428                                                NaN
# 2332429                                                NaN
# 2332430                                                NaN
# 2332431                                                NaN
# 2332432                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794563                                                0.0
# 1794564                                               -4.0
# 1794565                                               -1.0
# 1794566                                               -3.0
# 1794567                                               -2.0
# ...                                                    ...
# 2332428                                                NaN
# 2332429                                                NaN
# 2332430                                                NaN
# 2332431                                                NaN
# 2332432                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794563                                          -20.0
# 1794564                                          -24.0
# 1794565                                          -31.0
# 1794566                                          -33.0
# 1794567                                          -30.0
# ...                                                ...
# 2332428                                            NaN
# 2332429                                            NaN
# 2332430                                            NaN
# 2332431                                            NaN
# 2332432                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794563                                    -14.0
# 1794564                                    -17.0
# 1794565                                    -38.0
# 1794566                                    -39.0
# 1794567                                    -37.0
# ...                                          ...
# 2332428                                    -23.0
# 2332429                                    -22.0
# 2332430                                    -16.0
# 2332431                                    -20.0
# 2332432                                    -21.0
#
#          residential_percent_change_from_baseline
# 1794563                                       4.0
# 1794564                                       3.0
# 1794565                                      10.0
# 1794566                                      11.0
# 1794567                                      10.0
# ...                                           ...
# 2332428                                       NaN
# 2332429                                       NaN
# 2332430                                       NaN
# 2332431                                       NaN
# 2332432                                       NaN
#
# [80145 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794766  United States      Alabama  2020-08-01
# 1794767  United States      Alabama  2020-08-02
# 1794768  United States      Alabama  2020-08-03
# 1794769  United States      Alabama  2020-08-04
# 1794770  United States      Alabama  2020-08-05
# ...                ...          ...         ...
# 2330798  United States      Wyoming  2020-08-27
# 2330799  United States      Wyoming  2020-08-28
# 2330800  United States      Wyoming  2020-08-29
# 2330801  United States      Wyoming  2020-08-30
# 2330802  United States      Wyoming  2020-08-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794766                                               -9.0
# 1794767                                              -10.0
# 1794768                                               -1.0
# 1794769                                               -4.0
# 1794770                                               -2.0
# ...                                                    ...
# 2330798                                                5.0
# 2330799                                               -1.0
# 2330800                                               -6.0
# 2330801                                                1.0
# 2330802                                                7.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794766                                                8.0
# 1794767                                                3.0
# 1794768                                                6.0
# 1794769                                                5.0
# 1794770                                                4.0
# ...                                                    ...
# 2330798                                               15.0
# 2330799                                               11.0
# 2330800                                               10.0
# 2330801                                               14.0
# 2330802                                               12.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794766                                           15.0
# 1794767                                            8.0
# 1794768                                            1.0
# 1794769                                           -2.0
# 1794770                                            0.0
# ...                                                ...
# 2330798                                            2.0
# 2330799                                           -2.0
# 2330800                                           -2.0
# 2330801                                           -1.0
# 2330802                                            4.0
#
#          workplaces_percent_change_from_baseline  \
# 1794766                                     -9.0
# 1794767                                    -18.0
# 1794768                                    -30.0
# 1794769                                    -29.0
# 1794770                                    -30.0
# ...                                          ...
# 2330798                                    -28.0
# 2330799                                    -26.0
# 2330800                                    -14.0
# 2330801                                     -8.0
# 2330802                                    -25.0
#
#          residential_percent_change_from_baseline
# 1794766                                       2.0
# 1794767                                       3.0
# 1794768                                       7.0
# 1794769                                       7.0
# 1794770                                       7.0
# ...                                           ...
# 2330798                                       4.0
# 2330799                                       4.0
# 2330800                                      -2.0
# 2330801                                      -1.0
# 2330802                                       3.0
#
# [23461 rows x 8 columns]>

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794766  United States      Alabama  2020-08-01
# 1794767  United States      Alabama  2020-08-02
# 1794768  United States      Alabama  2020-08-03
# 1794769  United States      Alabama  2020-08-04
# 1794770  United States      Alabama  2020-08-05
# ...                ...          ...         ...
# 2330798  United States      Wyoming  2020-08-27
# 2330799  United States      Wyoming  2020-08-28
# 2330800  United States      Wyoming  2020-08-29
# 2330801  United States      Wyoming  2020-08-30
# 2330802  United States      Wyoming  2020-08-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794766                                          -0.051038
# 1794767                                          -0.127068
# 1794768                                           0.557203
# 1794769                                           0.329113
# 1794770                                           0.481173
# ...                                                    ...
# 2330798                                           1.013384
# 2330799                                           0.557203
# 2330800                                           0.177053
# 2330801                                           0.709264
# 2330802                                           1.165445
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794766                                           0.654844
# 1794767                                           0.221843
# 1794768                                           0.481644
# 1794769                                           0.395044
# 1794770                                           0.308443
# ...                                                    ...
# 2330798                                           1.261045
# 2330799                                           0.914644
# 2330800                                           0.828044
# 2330801                                           1.174445
# 2330802                                           1.001244
#
#          transit_stations_percent_change_from_baseline  \
# 1794766                                       0.917139
# 1794767                                       0.646514
# 1794768                                       0.375889
# 1794769                                       0.259907
# 1794770                                       0.337228
# ...                                                ...
# 2330798                                       0.414550
# 2330799                                       0.259907
# 2330800                                       0.259907
# 2330801                                       0.298568
# 2330802                                       0.491871
#
#          workplaces_percent_change_from_baseline  \
# 1794766                                 1.672286
# 1794767                                 0.886608
# 1794768                                -0.160961
# 1794769                                -0.073664
# 1794770                                -0.160961
# ...                                          ...
# 2330798                                 0.013634
# 2330799                                 0.188229
# 2330800                                 1.235798
# 2330801                                 1.759583
# 2330802                                 0.275526
#
#          residential_percent_change_from_baseline
# 1794766                                 -1.048847
# 1794767                                 -0.820413
# 1794768                                  0.093327
# 1794769                                  0.093327
# 1794770                                  0.093327
# ...                                           ...
# 2330798                                 -0.591978
# 2330799                                 -0.591978
# 2330800                                 -1.962587
# 2330801                                 -1.734152
# 2330802                                 -0.820413
#
# [23461 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.60549899 0.22371567 0.08850242 0.04995119]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0      1.877683  1.091718  0.115686  0.515388
# 1      1.090630  0.782335  0.241074  0.286793
# 2      0.526554 -0.662364  0.040785 -0.022607
# 3      0.369137 -0.449935  0.005156  0.065497
# 4      0.397551 -0.547485  0.101500 -0.083045
# ...         ...       ...       ...       ...
# 23456  1.484729 -0.776662 -0.468275  0.090330
# 23457  1.128390 -0.290491 -0.391820  0.173404
# 23458  1.991308  1.202472 -0.601418  0.283088
# 23459  2.516319  0.995703 -0.860531  0.105479
# 23460  1.687913 -0.485857 -0.365870 -0.193929
#
# [23461 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline  0.447255 -0.468299
# grocery_and_pharmacy_percent_change_from_baseline   0.445536 -0.423136
# transit_stations_percent_change_from_baseline       0.461226 -0.154863
# workplaces_percent_change_from_baseline             0.420114  0.584317
# residential_percent_change_from_baseline           -0.460690 -0.486049
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.149394 -0.745370
# grocery_and_pharmacy_percent_change_from_baseline  -0.474260  0.630006
# transit_stations_percent_change_from_baseline       0.848033  0.206718
# workplaces_percent_change_from_baseline            -0.142256 -0.038651
# residential_percent_change_from_baseline            0.115597  0.057362

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: retail, grocery, transit, workplaces")
print("Greatest contributors to PC2: workplaces")

print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: grocery")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: retail, grocery, transit, workplaces
# Greatest contributors to PC2: workplaces
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: grocery

# %%
# # find OPTIMAL value for kmeans
# from sklearn.cluster import KMeans
# data_kmeans = pd.DataFrame(pca_data)
# Sum_of_squared_distances = []
# K = range(1,7)
# for k in K:
#     km = KMeans(n_clusters=k)
#     km = km.fit(pca_data)
#     Sum_of_squared_distances.append(km.inertia_)
# plt.plot(K, Sum_of_squared_distances, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Sum_of_squared_distances')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0      1.877683  1.091718  0.115686  0.515388        1
# 1      1.090630  0.782335  0.241074  0.286793        3
# 2      0.526554 -0.662364  0.040785 -0.022607        2
# 3      0.369137 -0.449935  0.005156  0.065497        2
# 4      0.397551 -0.547485  0.101500 -0.083045        2
# ...         ...       ...       ...       ...      ...
# 23456  1.484729 -0.776662 -0.468275  0.090330        1
# 23457  1.128390 -0.290491 -0.391820  0.173404        1
# 23458  1.991308  1.202472 -0.601418  0.283088        3
# 23459  2.516319  0.995703 -0.860531  0.105479        1
# 23460  1.687913 -0.485857 -0.365870 -0.193929        1
#
# [23461 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0      1.877683  1.091718  0.115686  0.515388        1  Alabama
# 1      1.090630  0.782335  0.241074  0.286793        3  Alabama
# 2      0.526554 -0.662364  0.040785 -0.022607        2  Alabama
# 3      0.369137 -0.449935  0.005156  0.065497        2  Alabama
# 4      0.397551 -0.547485  0.101500 -0.083045        2  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 23456  1.484729 -0.776662 -0.468275  0.090330        1  Wyoming
# 23457  1.128390 -0.290491 -0.391820  0.173404        1  Wyoming
# 23458  1.991308  1.202472 -0.601418  0.283088        3  Wyoming
# 23459  2.516319  0.995703 -0.860531  0.105479        1  Wyoming
# 23460  1.687913 -0.485857 -0.365870 -0.193929        1  Wyoming
#
# [23461 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([1, 3, 2, 0], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 18, 'Arizona': 137, 'Arkansas': 12, 'California': 581, 'Colorado': 114, 'Connecticut': 27, 'Delaware': 21, 'District of Columbia': 30, 'Florida': 649, 'Georgia': 171, 'Hawaii': 145, 'Illinois': 51, 'Indiana': 20, 'Iowa': 1, 'Kentucky': 21, 'Louisiana': 102, 'Maryland': 193, 'Massachusetts': 124, 'Michigan': 85, 'Minnesota': 68, 'Mississippi': 8, 'Missouri': 52, 'Nevada': 50, 'New Jersey': 239, 'New Mexico': 110, 'New York': 279, 'North Carolina': 120, 'Ohio': 53, 'Oregon': 63, 'Pennsylvania': 150, 'Rhode Island': 31, 'South Carolina': 30, 'Tennessee': 52, 'Texas': 474, 'Utah': 30, 'Vermont': 23, 'Virginia': 260, 'Washington': 66, 'West Virginia': 1, 'Wisconsin': 34}, {'Alabama': 92, 'Alaska': 47, 'Arizona': 65, 'Arkansas': 83, 'California': 44, 'Colorado': 73, 'Connecticut': 23, 'Delaware': 32, 'Florida': 60, 'Georgia': 80, 'Idaho': 116, 'Illinois': 176, 'Indiana': 397, 'Iowa': 175, 'Kansas': 58, 'Kentucky': 52, 'Louisiana': 61, 'Maine': 98, 'Maryland': 10, 'Massachusetts': 46, 'Michigan': 160, 'Minnesota': 24, 'Mississippi': 25, 'Missouri': 191, 'Montana': 168, 'Nebraska': 85, 'Nevada': 42, 'New Hampshire': 37, 'New Jersey': 54, 'New Mexico': 1, 'New York': 108, 'North Carolina': 70, 'North Dakota': 45, 'Ohio': 407, 'Oklahoma': 160, 'Oregon': 149, 'Pennsylvania': 216, 'Rhode Island': 14, 'South Carolina': 66, 'South Dakota': 88, 'Tennessee': 193, 'Texas': 123, 'Utah': 129, 'Vermont': 6, 'Virginia': 78, 'Washington': 141, 'West Virginia': 38, 'Wisconsin': 116, 'Wyoming': 107}, {'Alabama': 248, 'Alaska': 39, 'Arizona': 81, 'Arkansas': 204, 'California': 307, 'Colorado': 134, 'Connecticut': 112, 'Delaware': 37, 'Florida': 192, 'Georgia': 366, 'Idaho': 42, 'Illinois': 359, 'Indiana': 307, 'Iowa': 90, 'Kansas': 137, 'Kentucky': 280, 'Louisiana': 287, 'Maine': 39, 'Maryland': 83, 'Massachusetts': 120, 'Michigan': 224, 'Minnesota': 156, 'Mississippi': 217, 'Missouri': 194, 'Montana': 10, 'Nebraska': 87, 'Nevada': 30, 'New Hampshire': 84, 'New Jersey': 151, 'New Mexico': 124, 'New York': 351, 'North Carolina': 462, 'North Dakota': 68, 'Ohio': 424, 'Oklahoma': 152, 'Oregon': 157, 'Pennsylvania': 396, 'Rhode Island': 38, 'South Carolina': 338, 'South Dakota': 3, 'Tennessee': 345, 'Texas': 706, 'Utah': 92, 'Vermont': 57, 'Virginia': 318, 'Washington': 271, 'West Virginia': 122, 'Wisconsin': 258, 'Wyoming': 4}, {'Alabama': 130, 'Alaska': 7, 'Arizona': 69, 'Arkansas': 55, 'California': 303, 'Colorado': 102, 'Connecticut': 49, 'Delaware': 20, 'District of Columbia': 1, 'Florida': 263, 'Georgia': 210, 'Idaho': 19, 'Illinois': 148, 'Indiana': 76, 'Iowa': 29, 'Kansas': 70, 'Kentucky': 66, 'Louisiana': 120, 'Maine': 13, 'Maryland': 103, 'Massachusetts': 94, 'Michigan': 101, 'Minnesota': 66, 'Mississippi': 64, 'Missouri': 101, 'Montana': 8, 'Nebraska': 35, 'Nevada': 35, 'New Hampshire': 20, 'New Jersey': 139, 'New Mexico': 71, 'New York': 204, 'North Carolina': 203, 'North Dakota': 35, 'Ohio': 153, 'Oklahoma': 58, 'Oregon': 89, 'Pennsylvania': 175, 'Rhode Island': 29, 'South Carolina': 127, 'Tennessee': 134, 'Texas': 377, 'Utah': 35, 'Vermont': 20, 'Virginia': 194, 'Washington': 115, 'West Virginia': 25, 'Wisconsin': 73, 'Wyoming': 1}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 18, 1: 92, 2: 248, 3: 130}
# {1: 47, 2: 39, 3: 7}
# {0: 137, 1: 65, 2: 81, 3: 69}
# {0: 12, 1: 83, 2: 204, 3: 55}
# {0: 581, 1: 44, 2: 307, 3: 303}
# {0: 114, 1: 73, 2: 134, 3: 102}
# {0: 27, 1: 23, 2: 112, 3: 49}
# {0: 21, 1: 32, 2: 37, 3: 20}
# {0: 30, 3: 1}
# {0: 649, 1: 60, 2: 192, 3: 263}
# {0: 171, 1: 80, 2: 366, 3: 210}
# {0: 145}
# {1: 116, 2: 42, 3: 19}
# {0: 51, 1: 176, 2: 359, 3: 148}
# {0: 20, 1: 397, 2: 307, 3: 76}
# {0: 1, 1: 175, 2: 90, 3: 29}
# {1: 58, 2: 137, 3: 70}
# {0: 21, 1: 52, 2: 280, 3: 66}
# {0: 102, 1: 61, 2: 287, 3: 120}
# {1: 98, 2: 39, 3: 13}
# {0: 193, 1: 10, 2: 83, 3: 103}
# {0: 124, 1: 46, 2: 120, 3: 94}
# {0: 85, 1: 160, 2: 224, 3: 101}
# {0: 68, 1: 24, 2: 156, 3: 66}
# {0: 8, 1: 25, 2: 217, 3: 64}
# {0: 52, 1: 191, 2: 194, 3: 101}
# {1: 168, 2: 10, 3: 8}
# {1: 85, 2: 87, 3: 35}
# {0: 50, 1: 42, 2: 30, 3: 35}
# {1: 37, 2: 84, 3: 20}
# {0: 239, 1: 54, 2: 151, 3: 139}
# {0: 110, 1: 1, 2: 124, 3: 71}
# {0: 279, 1: 108, 2: 351, 3: 204}
# {0: 120, 1: 70, 2: 462, 3: 203}
# {1: 45, 2: 68, 3: 35}
# {0: 53, 1: 407, 2: 424, 3: 153}
# {1: 160, 2: 152, 3: 58}
# {0: 63, 1: 149, 2: 157, 3: 89}
# {0: 150, 1: 216, 2: 396, 3: 175}
# {0: 31, 1: 14, 2: 38, 3: 29}
# {0: 30, 1: 66, 2: 338, 3: 127}
# {1: 88, 2: 3}
# {0: 52, 1: 193, 2: 345, 3: 134}
# {0: 474, 1: 123, 2: 706, 3: 377}
# {0: 30, 1: 129, 2: 92, 3: 35}
# {0: 23, 1: 6, 2: 57, 3: 20}
# {0: 260, 1: 78, 2: 318, 3: 194}
# {0: 66, 1: 141, 2: 271, 3: 115}
# {0: 1, 1: 38, 2: 122, 3: 25}
# {0: 34, 1: 116, 2: 258, 3: 73}
# {1: 107, 2: 4, 3: 1}
# {'Alabama': 2, 'Alaska': 1, 'Arizona': 0, 'Arkansas': 2, 'California': 0, 'Colorado': 2, 'Connecticut': 2, 'Delaware': 2, 'District of Columbia': 0, 'Florida': 0, 'Georgia': 2, 'Hawaii': 0, 'Idaho': 1, 'Illinois': 2, 'Indiana': 1, 'Iowa': 1, 'Kansas': 2, 'Kentucky': 2, 'Louisiana': 2, 'Maine': 1, 'Maryland': 0, 'Massachusetts': 0, 'Michigan': 2, 'Minnesota': 2, 'Mississippi': 2, 'Missouri': 2, 'Montana': 1, 'Nebraska': 2, 'Nevada': 0, 'New Hampshire': 2, 'New Jersey': 0, 'New Mexico': 2, 'New York': 2, 'North Carolina': 2, 'North Dakota': 2, 'Ohio': 2, 'Oklahoma': 1, 'Oregon': 2, 'Pennsylvania': 2, 'Rhode Island': 2, 'South Carolina': 2, 'South Dakota': 1, 'Tennessee': 2, 'Texas': 2, 'Utah': 1, 'Vermont': 2, 'Virginia': 2, 'Washington': 2, 'West Virginia': 2, 'Wisconsin': 2, 'Wyoming': 1}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: ['Alaska', 'Idaho', 'Indiana', 'Iowa', 'Maine', 'Montana', 'Oklahoma', 'South Dakota', 'Utah', 'Wyoming'], 2: ['Alabama', 'Arkansas', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin'], 3: [], 4: [], 0: ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'Nevada', 'New Jersey']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%15==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0     1.877683  1.091718  0.115686  0.515388       1  Alabama
# 1     0.941887  0.990855  0.297656  0.160430       3  Alabama
# 2     0.008290  0.166673  0.271689 -0.295972       2  Alabama
# 3     2.418657 -0.089314 -1.676212  0.320867       1  Alabama
# 4     2.042682  0.174879 -0.183188  0.525960       1  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1560  2.913716  0.924099 -0.095316 -0.063753       1  Wyoming
# 1561  1.494680 -0.735364  0.551628  0.184466       1  Wyoming
# 1562  2.102113  0.991243 -0.462009  0.446905       1  Wyoming
# 1563  3.382198  0.602276 -0.060958  0.675860       1  Wyoming
# 1564  1.687913 -0.485857 -0.365870 -0.193929       1  Wyoming
#
# [1565 rows x 6 columns]>

# %%
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0     1.877683  1.091718  0.115686  0.515388       1  Alabama
# 1     0.941887  0.990855  0.297656  0.160430       3  Alabama
# 2     0.008290  0.166673  0.271689 -0.295972       2  Alabama
# 3     2.418657 -0.089314 -1.676212  0.320867       1  Alabama
# 4     2.042682  0.174879 -0.183188  0.525960       1  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1560  2.913716  0.924099 -0.095316 -0.063753       1  Wyoming
# 1561  1.494680 -0.735364  0.551628  0.184466       1  Wyoming
# 1562  2.102113  0.991243 -0.462009  0.446905       1  Wyoming
# 1563  3.382198  0.602276 -0.060958  0.675860       1  Wyoming
# 1564  1.687913 -0.485857 -0.365870 -0.193929       1  Wyoming
#
# [1565 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([['Alaska', 'Idaho', 'Indiana', 'Iowa', 'Maine', 'Montana', 'Oklahoma', 'South Dakota', 'Utah', 'Wyoming'], ['Alabama', 'Arkansas', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin'], [], [], ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'Nevada', 'New Jersey']])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+6)*2

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers', hovertemplate="%{text}" +"<br>PC1: %{x}"+"<br>PC2: %{y}"+ "<br>PC3: %{z}<br> PC4(not normalized): %{marker.size:,}",
                    text=pca_2.State)

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("AUGUST Mobility KMeans.html")
                   )
# Out:
# 'AUGUST Mobility KMeans.html'
