# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-02")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332296                  US  United States      Wyoming  Weston County
# 2332297                  US  United States      Wyoming  Weston County
# 2332298                  US  United States      Wyoming  Weston County
# 2332299                  US  United States      Wyoming  Weston County
# 2332300                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332296        NaN             NaN           56045.0  2020-02-24
# 2332297        NaN             NaN           56045.0  2020-02-25
# 2332298        NaN             NaN           56045.0  2020-02-26
# 2332299        NaN             NaN           56045.0  2020-02-27
# 2332300        NaN             NaN           56045.0  2020-02-28
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332296                                                NaN
# 2332297                                                NaN
# 2332298                                                NaN
# 2332299                                                NaN
# 2332300                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332296                                                NaN
# 2332297                                               -9.0
# 2332298                                               -4.0
# 2332299                                                NaN
# 2332300                                                4.0
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332296                                 NaN
# 2332297                                 NaN
# 2332298                                 NaN
# 2332299                                 NaN
# 2332300                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332296                                            NaN
# 2332297                                            NaN
# 2332298                                            NaN
# 2332299                                            NaN
# 2332300                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332296                                     -4.0
# 2332297                                      2.0
# 2332298                                     -6.0
# 2332299                                      0.0
# 2332300                                      NaN
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332296                                       NaN
# 2332297                                       NaN
# 2332298                                       NaN
# 2332299                                       NaN
# 2332300                                       NaN
#
# [40553 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794395  United States          NaN  2020-02-15
# 1794396  United States          NaN  2020-02-16
# 1794397  United States          NaN  2020-02-17
# 1794398  United States          NaN  2020-02-18
# 1794399  United States          NaN  2020-02-19
# ...                ...          ...         ...
# 2332296  United States      Wyoming  2020-02-24
# 2332297  United States      Wyoming  2020-02-25
# 2332298  United States      Wyoming  2020-02-26
# 2332299  United States      Wyoming  2020-02-27
# 2332300  United States      Wyoming  2020-02-28
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332296                                                NaN
# 2332297                                                NaN
# 2332298                                                NaN
# 2332299                                                NaN
# 2332300                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332296                                                NaN
# 2332297                                               -9.0
# 2332298                                               -4.0
# 2332299                                                NaN
# 2332300                                                4.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332296                                            NaN
# 2332297                                            NaN
# 2332298                                            NaN
# 2332299                                            NaN
# 2332300                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332296                                     -4.0
# 2332297                                      2.0
# 2332298                                     -6.0
# 2332299                                      0.0
# 2332300                                      NaN
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332296                                       NaN
# 2332297                                       NaN
# 2332298                                       NaN
# 2332299                                       NaN
# 2332300                                       NaN
#
# [40553 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794598  United States      Alabama  2020-02-15
# 1794599  United States      Alabama  2020-02-16
# 1794600  United States      Alabama  2020-02-17
# 1794601  United States      Alabama  2020-02-18
# 1794602  United States      Alabama  2020-02-19
# ...                ...          ...         ...
# 2331537  United States      Wyoming  2020-02-24
# 2331538  United States      Wyoming  2020-02-25
# 2331539  United States      Wyoming  2020-02-26
# 2331540  United States      Wyoming  2020-02-27
# 2331541  United States      Wyoming  2020-02-28
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794598                                                5.0
# 1794599                                                0.0
# 1794600                                                3.0
# 1794601                                               -4.0
# 1794602                                                4.0
# ...                                                    ...
# 2331537                                                4.0
# 2331538                                                7.0
# 2331539                                                6.0
# 2331540                                               10.0
# 2331541                                               10.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794598                                                2.0
# 1794599                                               -2.0
# 1794600                                                0.0
# 1794601                                               -3.0
# 1794602                                                1.0
# ...                                                    ...
# 2331537                                               13.0
# 2331538                                                4.0
# 2331539                                                8.0
# 2331540                                               10.0
# 2331541                                               12.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794598                                            7.0
# 1794599                                            3.0
# 1794600                                            7.0
# 1794601                                           -1.0
# 1794602                                            4.0
# ...                                                ...
# 2331537                                          -13.0
# 2331538                                            1.0
# 2331539                                            0.0
# 2331540                                           13.0
# 2331541                                           38.0
#
#          workplaces_percent_change_from_baseline  \
# 1794598                                      2.0
# 1794599                                     -1.0
# 1794600                                    -17.0
# 1794601                                      1.0
# 1794602                                      1.0
# ...                                          ...
# 2331537                                      3.0
# 2331538                                      2.0
# 2331539                                      2.0
# 2331540                                     -1.0
# 2331541                                      4.0
#
#          residential_percent_change_from_baseline
# 1794598                                      -1.0
# 1794599                                       1.0
# 1794600                                       4.0
# 1794601                                       2.0
# 1794602                                       0.0
# ...                                           ...
# 2331537                                       0.0
# 2331538                                      -1.0
# 2331539                                       0.0
# 2331540                                      -1.0
# 2331541                                      -2.0
#
# [12068 rows x 8 columns]>

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794598  United States      Alabama  2020-02-15
# 1794599  United States      Alabama  2020-02-16
# 1794600  United States      Alabama  2020-02-17
# 1794601  United States      Alabama  2020-02-18
# 1794602  United States      Alabama  2020-02-19
# ...                ...          ...         ...
# 2331537  United States      Wyoming  2020-02-24
# 2331538  United States      Wyoming  2020-02-25
# 2331539  United States      Wyoming  2020-02-26
# 2331540  United States      Wyoming  2020-02-27
# 2331541  United States      Wyoming  2020-02-28
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794598                                          -0.083034
# 1794599                                          -0.825625
# 1794600                                          -0.380070
# 1794601                                          -1.419699
# 1794602                                          -0.231552
# ...                                                    ...
# 2331537                                          -0.231552
# 2331538                                           0.214003
# 2331539                                           0.065484
# 2331540                                           0.659558
# 2331541                                           0.659558
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794598                                           0.009149
# 1794599                                          -0.587642
# 1794600                                          -0.289246
# 1794601                                          -0.736839
# 1794602                                          -0.140049
# ...                                                    ...
# 2331537                                           1.650322
# 2331538                                           0.307544
# 2331539                                           0.904334
# 2331540                                           1.202729
# 2331541                                           1.501124
#
#          transit_stations_percent_change_from_baseline  \
# 1794598                                       0.276534
# 1794599                                      -0.096902
# 1794600                                       0.276534
# 1794601                                      -0.470338
# 1794602                                      -0.003543
# ...                                                ...
# 2331537                                      -1.590645
# 2331538                                      -0.283620
# 2331539                                      -0.376979
# 2331540                                       0.836688
# 2331541                                       3.170662
#
#          workplaces_percent_change_from_baseline  \
# 1794598                                 0.299933
# 1794599                                -0.092336
# 1794600                                -2.184436
# 1794601                                 0.169177
# 1794602                                 0.169177
# ...                                          ...
# 2331537                                 0.430690
# 2331538                                 0.299933
# 2331539                                 0.299933
# 2331540                                -0.092336
# 2331541                                 0.561446
#
#          residential_percent_change_from_baseline
# 1794598                                 -0.533359
# 1794599                                  0.410836
# 1794600                                  1.827127
# 1794601                                  0.882933
# 1794602                                 -0.061262
# ...                                           ...
# 2331537                                 -0.061262
# 2331538                                 -0.533359
# 2331539                                 -0.061262
# 2331540                                 -0.533359
# 2331541                                 -1.005456
#
# [12068 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.46348438 0.24230144 0.16348582 0.10679269]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0      0.511183 -0.316860  0.223095 -0.050869
# 1     -0.895234 -0.502970  0.345292 -0.200060
# 2     -2.256347  1.706265  0.527942 -0.323780
# 3     -1.479618 -0.991697  0.215990 -0.504069
# 4     -0.040162 -0.301936  0.097388 -0.057850
# ...         ...       ...       ...       ...
# 12063  0.296313 -0.220701 -2.099477 -0.951732
# 12064  0.571289 -0.206172 -0.451826  0.066905
# 12065  0.449450  0.074945 -0.752722 -0.493502
# 12066  1.312280  0.946770  0.041396 -0.465552
# 12067  2.780782  1.184220  1.919793 -1.115806
#
# [12068 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline  0.408636  0.524776
# grocery_and_pharmacy_percent_change_from_baseline   0.412979  0.392752
# transit_stations_percent_change_from_baseline       0.329384  0.289893
# workplaces_percent_change_from_baseline             0.458313 -0.618888
# residential_percent_change_from_baseline           -0.586447  0.321396
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.170170  0.681572
# grocery_and_pharmacy_percent_change_from_baseline  -0.454195 -0.682775
# transit_stations_percent_change_from_baseline       0.872699 -0.212547
# workplaces_percent_change_from_baseline             0.005253 -0.033634
# residential_percent_change_from_baseline            0.055845 -0.151560

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: retail, grocery, workplaces")
print("Greatest contributors to PC2: retail, grocery, residential, transit")

print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: retail")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: retail, grocery, workplaces
# Greatest contributors to PC2: retail, grocery, residential, transit
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: retail

# %%
# # find OPTIMAL value for kmeans
# from sklearn.cluster import KMeans
# data_kmeans = pd.DataFrame(pca_data)
# Sum_of_squared_distances = []
# K = range(1,7)
# for k in K:
#     km = KMeans(n_clusters=k)
#     km = km.fit(pca_data)
#     Sum_of_squared_distances.append(km.inertia_)
# plt.plot(K, Sum_of_squared_distances, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Sum_of_squared_distances')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0      0.511183 -0.316860  0.223095 -0.050869        3
# 1     -0.895234 -0.502970  0.345292 -0.200060        0
# 2     -2.256347  1.706265  0.527942 -0.323780        2
# 3     -1.479618 -0.991697  0.215990 -0.504069        0
# 4     -0.040162 -0.301936  0.097388 -0.057850        3
# ...         ...       ...       ...       ...      ...
# 12063  0.296313 -0.220701 -2.099477 -0.951732        3
# 12064  0.571289 -0.206172 -0.451826  0.066905        3
# 12065  0.449450  0.074945 -0.752722 -0.493502        3
# 12066  1.312280  0.946770  0.041396 -0.465552        1
# 12067  2.780782  1.184220  1.919793 -1.115806        1
#
# [12068 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0      0.511183 -0.316860  0.223095 -0.050869        3  Alabama
# 1     -0.895234 -0.502970  0.345292 -0.200060        0  Alabama
# 2     -2.256347  1.706265  0.527942 -0.323780        2  Alabama
# 3     -1.479618 -0.991697  0.215990 -0.504069        0  Alabama
# 4     -0.040162 -0.301936  0.097388 -0.057850        3  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 12063  0.296313 -0.220701 -2.099477 -0.951732        3  Wyoming
# 12064  0.571289 -0.206172 -0.451826  0.066905        3  Wyoming
# 12065  0.449450  0.074945 -0.752722 -0.493502        3  Wyoming
# 12066  1.312280  0.946770  0.041396 -0.465552        1  Wyoming
# 12067  2.780782  1.184220  1.919793 -1.115806        1  Wyoming
#
# [12068 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([3, 0, 2, 1], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 74, 'Alaska': 11, 'Arizona': 24, 'Arkansas': 58, 'California': 142, 'Colorado': 65, 'Connecticut': 46, 'Delaware': 10, 'District of Columbia': 8, 'Florida': 126, 'Georgia': 133, 'Hawaii': 23, 'Idaho': 8, 'Illinois': 114, 'Indiana': 93, 'Iowa': 47, 'Kansas': 61, 'Kentucky': 65, 'Louisiana': 88, 'Maine': 9, 'Maryland': 76, 'Massachusetts': 68, 'Michigan': 84, 'Minnesota': 48, 'Mississippi': 50, 'Missouri': 62, 'Montana': 15, 'Nebraska': 21, 'Nevada': 6, 'New Hampshire': 29, 'New Jersey': 118, 'New Mexico': 18, 'New York': 180, 'North Carolina': 123, 'North Dakota': 25, 'Ohio': 130, 'Oklahoma': 45, 'Oregon': 22, 'Pennsylvania': 158, 'Rhode Island': 23, 'South Carolina': 108, 'South Dakota': 10, 'Tennessee': 121, 'Texas': 202, 'Utah': 23, 'Vermont': 14, 'Virginia': 144, 'Washington': 9, 'West Virginia': 29, 'Wisconsin': 92, 'Wyoming': 15}, {'Alabama': 63, 'Alaska': 15, 'Arizona': 38, 'Arkansas': 51, 'California': 60, 'Colorado': 21, 'Connecticut': 4, 'Delaware': 3, 'Florida': 70, 'Georgia': 82, 'Idaho': 38, 'Illinois': 91, 'Indiana': 83, 'Iowa': 68, 'Kansas': 44, 'Kentucky': 43, 'Louisiana': 86, 'Maine': 15, 'Maryland': 6, 'Massachusetts': 5, 'Michigan': 52, 'Minnesota': 18, 'Mississippi': 60, 'Missouri': 90, 'Montana': 19, 'Nebraska': 34, 'Nevada': 20, 'New Hampshire': 4, 'New Jersey': 14, 'New Mexico': 64, 'New York': 30, 'North Carolina': 62, 'North Dakota': 16, 'Ohio': 54, 'Oklahoma': 58, 'Oregon': 34, 'Pennsylvania': 35, 'South Carolina': 63, 'South Dakota': 15, 'Tennessee': 64, 'Texas': 213, 'Utah': 55, 'Vermont': 5, 'Virginia': 57, 'Washington': 80, 'West Virginia': 8, 'Wisconsin': 47, 'Wyoming': 23}, {'Alabama': 17, 'Alaska': 3, 'Arizona': 13, 'Arkansas': 12, 'California': 44, 'Colorado': 15, 'Connecticut': 8, 'Delaware': 4, 'District of Columbia': 1, 'Florida': 35, 'Georgia': 36, 'Hawaii': 5, 'Idaho': 5, 'Illinois': 30, 'Indiana': 26, 'Iowa': 4, 'Kansas': 7, 'Kentucky': 15, 'Louisiana': 30, 'Maine': 13, 'Maryland': 14, 'Massachusetts': 14, 'Michigan': 36, 'Minnesota': 11, 'Mississippi': 16, 'Missouri': 19, 'Montana': 7, 'Nebraska': 5, 'Nevada': 5, 'New Hampshire': 7, 'New Jersey': 21, 'New Mexico': 11, 'New York': 65, 'North Carolina': 49, 'North Dakota': 6, 'Ohio': 53, 'Oklahoma': 12, 'Oregon': 14, 'Pennsylvania': 32, 'Rhode Island': 4, 'South Carolina': 15, 'South Dakota': 4, 'Tennessee': 21, 'Texas': 47, 'Utah': 10, 'Vermont': 5, 'Virginia': 37, 'Washington': 22, 'West Virginia': 11, 'Wisconsin': 2, 'Wyoming': 7}, {'Alabama': 82, 'Alaska': 24, 'Arizona': 98, 'Arkansas': 65, 'California': 337, 'Colorado': 125, 'Connecticut': 57, 'Delaware': 38, 'District of Columbia': 6, 'Florida': 342, 'Georgia': 155, 'Hawaii': 42, 'Idaho': 63, 'Illinois': 147, 'Indiana': 205, 'Iowa': 47, 'Kansas': 76, 'Kentucky': 99, 'Louisiana': 80, 'Maine': 34, 'Maryland': 112, 'Massachusetts': 87, 'Michigan': 118, 'Minnesota': 88, 'Mississippi': 42, 'Missouri': 110, 'Montana': 57, 'Nebraska': 43, 'Nevada': 40, 'New Hampshire': 39, 'New Jersey': 155, 'New Mexico': 69, 'New York': 201, 'North Carolina': 174, 'North Dakota': 42, 'Ohio': 305, 'Oklahoma': 81, 'Oregon': 149, 'Pennsylvania': 257, 'Rhode Island': 31, 'South Carolina': 102, 'South Dakota': 18, 'Tennessee': 171, 'Texas': 379, 'Utah': 63, 'Vermont': 18, 'Virginia': 237, 'Washington': 199, 'West Virginia': 46, 'Wisconsin': 125, 'Wyoming': 30}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 74, 1: 63, 2: 17, 3: 82}
# {0: 11, 1: 15, 2: 3, 3: 24}
# {0: 24, 1: 38, 2: 13, 3: 98}
# {0: 58, 1: 51, 2: 12, 3: 65}
# {0: 142, 1: 60, 2: 44, 3: 337}
# {0: 65, 1: 21, 2: 15, 3: 125}
# {0: 46, 1: 4, 2: 8, 3: 57}
# {0: 10, 1: 3, 2: 4, 3: 38}
# {0: 8, 2: 1, 3: 6}
# {0: 126, 1: 70, 2: 35, 3: 342}
# {0: 133, 1: 82, 2: 36, 3: 155}
# {0: 23, 2: 5, 3: 42}
# {0: 8, 1: 38, 2: 5, 3: 63}
# {0: 114, 1: 91, 2: 30, 3: 147}
# {0: 93, 1: 83, 2: 26, 3: 205}
# {0: 47, 1: 68, 2: 4, 3: 47}
# {0: 61, 1: 44, 2: 7, 3: 76}
# {0: 65, 1: 43, 2: 15, 3: 99}
# {0: 88, 1: 86, 2: 30, 3: 80}
# {0: 9, 1: 15, 2: 13, 3: 34}
# {0: 76, 1: 6, 2: 14, 3: 112}
# {0: 68, 1: 5, 2: 14, 3: 87}
# {0: 84, 1: 52, 2: 36, 3: 118}
# {0: 48, 1: 18, 2: 11, 3: 88}
# {0: 50, 1: 60, 2: 16, 3: 42}
# {0: 62, 1: 90, 2: 19, 3: 110}
# {0: 15, 1: 19, 2: 7, 3: 57}
# {0: 21, 1: 34, 2: 5, 3: 43}
# {0: 6, 1: 20, 2: 5, 3: 40}
# {0: 29, 1: 4, 2: 7, 3: 39}
# {0: 118, 1: 14, 2: 21, 3: 155}
# {0: 18, 1: 64, 2: 11, 3: 69}
# {0: 180, 1: 30, 2: 65, 3: 201}
# {0: 123, 1: 62, 2: 49, 3: 174}
# {0: 25, 1: 16, 2: 6, 3: 42}
# {0: 130, 1: 54, 2: 53, 3: 305}
# {0: 45, 1: 58, 2: 12, 3: 81}
# {0: 22, 1: 34, 2: 14, 3: 149}
# {0: 158, 1: 35, 2: 32, 3: 257}
# {0: 23, 2: 4, 3: 31}
# {0: 108, 1: 63, 2: 15, 3: 102}
# {0: 10, 1: 15, 2: 4, 3: 18}
# {0: 121, 1: 64, 2: 21, 3: 171}
# {0: 202, 1: 213, 2: 47, 3: 379}
# {0: 23, 1: 55, 2: 10, 3: 63}
# {0: 14, 1: 5, 2: 5, 3: 18}
# {0: 144, 1: 57, 2: 37, 3: 237}
# {0: 9, 1: 80, 2: 22, 3: 199}
# {0: 29, 1: 8, 2: 11, 3: 46}
# {0: 92, 1: 47, 2: 2, 3: 125}
# {0: 15, 1: 23, 2: 7, 3: 30}
# {'Alabama': 3, 'Alaska': 3, 'Arizona': 3, 'Arkansas': 3, 'California': 3, 'Colorado': 3, 'Connecticut': 3, 'Delaware': 3, 'District of Columbia': 0, 'Florida': 3, 'Georgia': 3, 'Hawaii': 3, 'Idaho': 3, 'Illinois': 3, 'Indiana': 3, 'Iowa': 1, 'Kansas': 3, 'Kentucky': 3, 'Louisiana': 0, 'Maine': 3, 'Maryland': 3, 'Massachusetts': 3, 'Michigan': 3, 'Minnesota': 3, 'Mississippi': 1, 'Missouri': 3, 'Montana': 3, 'Nebraska': 3, 'Nevada': 3, 'New Hampshire': 3, 'New Jersey': 3, 'New Mexico': 3, 'New York': 3, 'North Carolina': 3, 'North Dakota': 3, 'Ohio': 3, 'Oklahoma': 3, 'Oregon': 3, 'Pennsylvania': 3, 'Rhode Island': 3, 'South Carolina': 0, 'South Dakota': 3, 'Tennessee': 3, 'Texas': 3, 'Utah': 3, 'Vermont': 3, 'Virginia': 3, 'Washington': 3, 'West Virginia': 3, 'Wisconsin': 3, 'Wyoming': 3}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: ['Iowa', 'Mississippi'], 2: [], 3: ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'], 4: [], 0: ['District of Columbia', 'Louisiana', 'South Carolina']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%15==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of          PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    0.511183 -0.316860  0.223095 -0.050869       3  Alabama
# 1    2.402937  0.756021 -0.699974  0.179275       1  Alabama
# 2   -1.734853  0.875343  0.659842 -0.618618       0  Alabama
# 3   -1.508794 -0.883709  0.296778 -0.519515       0  Alabama
# 4    0.846768 -0.356439  0.487154  0.590279       3  Alabama
# ..        ...       ...       ...       ...     ...      ...
# 800  1.398983  0.276802  0.269889 -0.709193       1  Wyoming
# 801  1.298889 -0.164930  0.358296  0.252031       3  Wyoming
# 802 -4.473771  4.489991  1.562970 -0.081501       2  Wyoming
# 803 -4.268551  2.180022  0.984569 -0.475797       2  Wyoming
# 804 -1.054865 -1.033044 -0.044947  0.332479       0  Wyoming
#
# [805 rows x 6 columns]>

# %%
pca_2
# Out:
#          PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    0.511183 -0.316860  0.223095 -0.050869       3  Alabama
# 1    2.402937  0.756021 -0.699974  0.179275       1  Alabama
# 2   -1.734853  0.875343  0.659842 -0.618618       0  Alabama
# 3   -1.508794 -0.883709  0.296778 -0.519515       0  Alabama
# 4    0.846768 -0.356439  0.487154  0.590279       3  Alabama
# ..        ...       ...       ...       ...     ...      ...
# 800  1.398983  0.276802  0.269889 -0.709193       1  Wyoming
# 801  1.298889 -0.164930  0.358296  0.252031       3  Wyoming
# 802 -4.473771  4.489991  1.562970 -0.081501       2  Wyoming
# 803 -4.268551  2.180022  0.984569 -0.475797       2  Wyoming
# 804 -1.054865 -1.033044 -0.044947  0.332479       0  Wyoming
#
# [805 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([['Iowa', 'Mississippi'], [], ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'], [], ['District of Columbia', 'Louisiana', 'South Carolina']])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+6)*2

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers', hovertemplate="%{text}" +"<br>PC1: %{x}"+"<br>PC2: %{y}"+ "<br>PC3: %{z}<br> PC4(not normalized): %{marker.size:,}",
                    text=pca_2.State)

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("Feb Mobility KMeans.html")
                   )
# Out:
# 'Feb Mobility KMeans.html'
