# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-07")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794532                  US  United States          NaN            NaN
# 1794533                  US  United States          NaN            NaN
# 1794534                  US  United States          NaN            NaN
# 1794535                  US  United States          NaN            NaN
# 1794536                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332407                  US  United States      Wyoming  Weston County
# 2332408                  US  United States      Wyoming  Weston County
# 2332409                  US  United States      Wyoming  Weston County
# 2332410                  US  United States      Wyoming  Weston County
# 2332411                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794532        NaN             NaN               NaN  2020-07-01
# 1794533        NaN             NaN               NaN  2020-07-02
# 1794534        NaN             NaN               NaN  2020-07-03
# 1794535        NaN             NaN               NaN  2020-07-04
# 1794536        NaN             NaN               NaN  2020-07-05
# ...            ...             ...               ...         ...
# 2332407        NaN             NaN           56045.0  2020-07-27
# 2332408        NaN             NaN           56045.0  2020-07-28
# 2332409        NaN             NaN           56045.0  2020-07-29
# 2332410        NaN             NaN           56045.0  2020-07-30
# 2332411        NaN             NaN           56045.0  2020-07-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794532                                               -7.0
# 1794533                                               -4.0
# 1794534                                              -10.0
# 1794535                                              -35.0
# 1794536                                              -22.0
# ...                                                    ...
# 2332407                                                NaN
# 2332408                                                NaN
# 2332409                                                NaN
# 2332410                                                NaN
# 2332411                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794532                                                4.0
# 1794533                                               11.0
# 1794534                                               11.0
# 1794535                                               -2.0
# 1794536                                              -10.0
# ...                                                    ...
# 2332407                                                NaN
# 2332408                                                NaN
# 2332409                                                NaN
# 2332410                                                NaN
# 2332411                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794532                                54.0
# 1794533                                77.0
# 1794534                                86.0
# 1794535                                81.0
# 1794536                                53.0
# ...                                     ...
# 2332407                                 NaN
# 2332408                                 NaN
# 2332409                                 NaN
# 2332410                                 NaN
# 2332411                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794532                                          -27.0
# 1794533                                          -24.0
# 1794534                                          -30.0
# 1794535                                          -30.0
# 1794536                                          -23.0
# ...                                                ...
# 2332407                                            NaN
# 2332408                                            NaN
# 2332409                                            NaN
# 2332410                                            NaN
# 2332411                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794532                                    -37.0
# 1794533                                    -39.0
# 1794534                                    -57.0
# 1794535                                    -28.0
# 1794536                                    -19.0
# ...                                          ...
# 2332407                                    -29.0
# 2332408                                    -24.0
# 2332409                                    -29.0
# 2332410                                    -29.0
# 2332411                                    -26.0
#
#          residential_percent_change_from_baseline
# 1794532                                      10.0
# 1794533                                      10.0
# 1794534                                      14.0
# 1794535                                       5.0
# 1794536                                       3.0
# ...                                           ...
# 2332407                                       NaN
# 2332408                                       NaN
# 2332409                                       NaN
# 2332410                                       NaN
# 2332411                                       NaN
#
# [81686 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794532  United States          NaN  2020-07-01
# 1794533  United States          NaN  2020-07-02
# 1794534  United States          NaN  2020-07-03
# 1794535  United States          NaN  2020-07-04
# 1794536  United States          NaN  2020-07-05
# ...                ...          ...         ...
# 2332407  United States      Wyoming  2020-07-27
# 2332408  United States      Wyoming  2020-07-28
# 2332409  United States      Wyoming  2020-07-29
# 2332410  United States      Wyoming  2020-07-30
# 2332411  United States      Wyoming  2020-07-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794532                                               -7.0
# 1794533                                               -4.0
# 1794534                                              -10.0
# 1794535                                              -35.0
# 1794536                                              -22.0
# ...                                                    ...
# 2332407                                                NaN
# 2332408                                                NaN
# 2332409                                                NaN
# 2332410                                                NaN
# 2332411                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794532                                                4.0
# 1794533                                               11.0
# 1794534                                               11.0
# 1794535                                               -2.0
# 1794536                                              -10.0
# ...                                                    ...
# 2332407                                                NaN
# 2332408                                                NaN
# 2332409                                                NaN
# 2332410                                                NaN
# 2332411                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794532                                          -27.0
# 1794533                                          -24.0
# 1794534                                          -30.0
# 1794535                                          -30.0
# 1794536                                          -23.0
# ...                                                ...
# 2332407                                            NaN
# 2332408                                            NaN
# 2332409                                            NaN
# 2332410                                            NaN
# 2332411                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794532                                    -37.0
# 1794533                                    -39.0
# 1794534                                    -57.0
# 1794535                                    -28.0
# 1794536                                    -19.0
# ...                                          ...
# 2332407                                    -29.0
# 2332408                                    -24.0
# 2332409                                    -29.0
# 2332410                                    -29.0
# 2332411                                    -26.0
#
#          residential_percent_change_from_baseline
# 1794532                                      10.0
# 1794533                                      10.0
# 1794534                                      14.0
# 1794535                                       5.0
# 1794536                                       3.0
# ...                                           ...
# 2332407                                       NaN
# 2332408                                       NaN
# 2332409                                       NaN
# 2332410                                       NaN
# 2332411                                       NaN
#
# [81686 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794735  United States      Alabama  2020-07-01
# 1794736  United States      Alabama  2020-07-02
# 1794737  United States      Alabama  2020-07-03
# 1794738  United States      Alabama  2020-07-04
# 1794739  United States      Alabama  2020-07-05
# ...                ...          ...         ...
# 2330767  United States      Wyoming  2020-07-27
# 2330768  United States      Wyoming  2020-07-28
# 2330769  United States      Wyoming  2020-07-29
# 2330770  United States      Wyoming  2020-07-30
# 2330771  United States      Wyoming  2020-07-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794735                                                4.0
# 1794736                                                6.0
# 1794737                                               -3.0
# 1794738                                              -35.0
# 1794739                                              -18.0
# ...                                                    ...
# 2330767                                                5.0
# 2330768                                                2.0
# 2330769                                                5.0
# 2330770                                                6.0
# 2330771                                               -1.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794735                                                9.0
# 1794736                                               18.0
# 1794737                                               18.0
# 1794738                                                0.0
# 1794739                                               -7.0
# ...                                                    ...
# 2330767                                               18.0
# 2330768                                               14.0
# 2330769                                               10.0
# 2330770                                               15.0
# 2330771                                               17.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794735                                            5.0
# 1794736                                           12.0
# 1794737                                            0.0
# 1794738                                           -9.0
# 1794739                                           11.0
# ...                                                ...
# 2330767                                           18.0
# 2330768                                            0.0
# 2330769                                           10.0
# 2330770                                           13.0
# 2330771                                            6.0
#
#          workplaces_percent_change_from_baseline  \
# 1794735                                    -32.0
# 1794736                                    -34.0
# 1794737                                    -55.0
# 1794738                                    -28.0
# 1794739                                    -21.0
# ...                                          ...
# 2330767                                    -26.0
# 2330768                                    -25.0
# 2330769                                    -27.0
# 2330770                                    -29.0
# 2330771                                    -28.0
#
#          residential_percent_change_from_baseline
# 1794735                                       8.0
# 1794736                                       8.0
# 1794737                                      14.0
# 1794738                                       4.0
# 1794739                                       4.0
# ...                                           ...
# 2330767                                       4.0
# 2330768                                       5.0
# 2330769                                       5.0
# 2330770                                       4.0
# 2330771                                       4.0
#
# [23691 rows x 8 columns]>

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794735  United States      Alabama  2020-07-01
# 1794736  United States      Alabama  2020-07-02
# 1794737  United States      Alabama  2020-07-03
# 1794738  United States      Alabama  2020-07-04
# 1794739  United States      Alabama  2020-07-05
# ...                ...          ...         ...
# 2330767  United States      Wyoming  2020-07-27
# 2330768  United States      Wyoming  2020-07-28
# 2330769  United States      Wyoming  2020-07-29
# 2330770  United States      Wyoming  2020-07-30
# 2330771  United States      Wyoming  2020-07-31
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794735                                           0.877883
# 1794736                                           1.016991
# 1794737                                           0.391004
# 1794738                                          -1.834727
# 1794739                                          -0.652307
# ...                                                    ...
# 2330767                                           0.947437
# 2330768                                           0.738775
# 2330769                                           0.947437
# 2330770                                           1.016991
# 2330771                                           0.530113
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794735                                           0.486546
# 1794736                                           1.222134
# 1794737                                           1.222134
# 1794738                                          -0.249043
# 1794739                                          -0.821167
# ...                                                    ...
# 2330767                                           1.222134
# 2330768                                           0.895206
# 2330769                                           0.568278
# 2330770                                           0.976938
# 2330771                                           1.140402
#
#          transit_stations_percent_change_from_baseline  \
# 1794735                                       0.498443
# 1794736                                       0.767890
# 1794737                                       0.305981
# 1794738                                      -0.040450
# 1794739                                       0.729397
# ...                                                ...
# 2330767                                       0.998844
# 2330768                                       0.305981
# 2330769                                       0.690905
# 2330770                                       0.806382
# 2330771                                       0.536935
#
#          workplaces_percent_change_from_baseline  \
# 1794735                                -0.068377
# 1794736                                -0.244561
# 1794737                                -2.094494
# 1794738                                 0.283991
# 1794739                                 0.900635
# ...                                          ...
# 2330767                                 0.460175
# 2330768                                 0.548267
# 2330769                                 0.372083
# 2330770                                 0.195899
# 2330771                                 0.283991
#
#          residential_percent_change_from_baseline
# 1794735                                 -0.006312
# 1794736                                 -0.006312
# 1794737                                  1.363591
# 1794738                                 -0.919581
# 1794739                                 -0.919581
# ...                                           ...
# 2330767                                 -0.919581
# 2330768                                 -0.691264
# 2330769                                 -0.691264
# 2330770                                 -0.919581
# 2330771                                 -0.919581
#
# [23691 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.56091676 0.27659068 0.08682532 0.05341374]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0     -0.820826  0.713125  0.084098  0.266282
# 1     -1.261607  1.249806 -0.037052 -0.141222
# 2      0.617683  2.664099  0.160162 -0.669115
# 3      0.401599 -1.532841  0.080219 -1.285597
# 4     -0.497584 -1.543884  0.779797 -0.129082
# ...         ...       ...       ...       ...
# 23686 -2.051527  0.399971 -0.112367 -0.221687
# 23687 -1.407237  0.124666 -0.471886 -0.004707
# 23688 -1.477699  0.222958 -0.000015  0.234080
# 23689 -1.779743  0.455649 -0.135064 -0.022138
# 23690 -1.535868  0.226269 -0.388304 -0.416606
#
# [23691 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline -0.447612  0.446385
# grocery_and_pharmacy_percent_change_from_baseline  -0.430646  0.455185
# transit_stations_percent_change_from_baseline      -0.485945  0.123014
# workplaces_percent_change_from_baseline            -0.392767 -0.605108
# residential_percent_change_from_baseline            0.473053  0.460715
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.123094  0.763498
# grocery_and_pharmacy_percent_change_from_baseline  -0.475279 -0.582286
# transit_stations_percent_change_from_baseline       0.836443 -0.220832
# workplaces_percent_change_from_baseline            -0.114695  0.146935
# residential_percent_change_from_baseline            0.214862  0.087498

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: residential")
print("Greatest contributors to PC2: residential, retail, grocery")

print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: retail")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: residential
# Greatest contributors to PC2: residential, retail, grocery
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: retail

# %%
# # find OPTIMAL value for kmeans
# from sklearn.cluster import KMeans
# data_kmeans = pd.DataFrame(pca_data)
# Sum_of_squared_distances = []
# K = range(1,7)
# for k in K:
#     km = KMeans(n_clusters=k)
#     km = km.fit(pca_data)
#     Sum_of_squared_distances.append(km.inertia_)
# plt.plot(K, Sum_of_squared_distances, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Sum_of_squared_distances')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0     -0.820826  0.713125  0.084098  0.266282        3
# 1     -1.261607  1.249806 -0.037052 -0.141222        1
# 2      0.617683  2.664099  0.160162 -0.669115        3
# 3      0.401599 -1.532841  0.080219 -1.285597        0
# 4     -0.497584 -1.543884  0.779797 -0.129082        0
# ...         ...       ...       ...       ...      ...
# 23686 -2.051527  0.399971 -0.112367 -0.221687        1
# 23687 -1.407237  0.124666 -0.471886 -0.004707        1
# 23688 -1.477699  0.222958 -0.000015  0.234080        1
# 23689 -1.779743  0.455649 -0.135064 -0.022138        1
# 23690 -1.535868  0.226269 -0.388304 -0.416606        1
#
# [23691 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0     -0.820826  0.713125  0.084098  0.266282        3  Alabama
# 1     -1.261607  1.249806 -0.037052 -0.141222        1  Alabama
# 2      0.617683  2.664099  0.160162 -0.669115        3  Alabama
# 3      0.401599 -1.532841  0.080219 -1.285597        0  Alabama
# 4     -0.497584 -1.543884  0.779797 -0.129082        0  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 23686 -2.051527  0.399971 -0.112367 -0.221687        1  Wyoming
# 23687 -1.407237  0.124666 -0.471886 -0.004707        1  Wyoming
# 23688 -1.477699  0.222958 -0.000015  0.234080        1  Wyoming
# 23689 -1.779743  0.455649 -0.135064 -0.022138        1  Wyoming
# 23690 -1.535868  0.226269 -0.388304 -0.416606        1  Wyoming
#
# [23691 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([3, 1, 0, 2], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 93, 'Alaska': 14, 'Arizona': 51, 'Arkansas': 50, 'California': 251, 'Colorado': 87, 'Connecticut': 51, 'Delaware': 20, 'District of Columbia': 3, 'Florida': 238, 'Georgia': 155, 'Hawaii': 2, 'Idaho': 22, 'Illinois': 147, 'Indiana': 108, 'Iowa': 52, 'Kansas': 59, 'Kentucky': 57, 'Louisiana': 96, 'Maine': 18, 'Maryland': 82, 'Massachusetts': 80, 'Michigan': 91, 'Minnesota': 61, 'Mississippi': 42, 'Missouri': 93, 'Montana': 16, 'Nebraska': 33, 'Nevada': 20, 'New Hampshire': 24, 'New Jersey': 122, 'New Mexico': 62, 'New York': 187, 'North Carolina': 164, 'North Dakota': 32, 'Ohio': 156, 'Oklahoma': 46, 'Oregon': 73, 'Pennsylvania': 171, 'Rhode Island': 24, 'South Carolina': 97, 'South Dakota': 5, 'Tennessee': 127, 'Texas': 272, 'Utah': 34, 'Vermont': 16, 'Virginia': 162, 'Washington': 100, 'West Virginia': 17, 'Wisconsin': 73, 'Wyoming': 8}, {'Alabama': 113, 'Alaska': 53, 'Arizona': 71, 'Arkansas': 84, 'California': 54, 'Colorado': 81, 'Connecticut': 2, 'Delaware': 31, 'Florida': 80, 'Georgia': 88, 'Idaho': 115, 'Illinois': 145, 'Indiana': 374, 'Iowa': 117, 'Kansas': 75, 'Kentucky': 67, 'Louisiana': 54, 'Maine': 83, 'Maryland': 12, 'Massachusetts': 37, 'Michigan': 189, 'Minnesota': 23, 'Mississippi': 31, 'Missouri': 185, 'Montana': 164, 'Nebraska': 87, 'Nevada': 42, 'New Hampshire': 27, 'New Jersey': 39, 'New Mexico': 11, 'New York': 106, 'North Carolina': 96, 'North Dakota': 61, 'Ohio': 422, 'Oklahoma': 164, 'Oregon': 173, 'Pennsylvania': 225, 'Rhode Island': 19, 'South Carolina': 77, 'South Dakota': 86, 'Tennessee': 194, 'Texas': 80, 'Utah': 119, 'Vermont': 4, 'Virginia': 83, 'Washington': 150, 'West Virginia': 54, 'Wisconsin': 154, 'Wyoming': 105}, {'Alabama': 16, 'Arizona': 152, 'Arkansas': 16, 'California': 549, 'Colorado': 102, 'Connecticut': 48, 'Delaware': 22, 'District of Columbia': 28, 'Florida': 605, 'Georgia': 176, 'Hawaii': 143, 'Idaho': 1, 'Illinois': 68, 'Indiana': 27, 'Iowa': 6, 'Kentucky': 14, 'Louisiana': 83, 'Maryland': 197, 'Massachusetts': 138, 'Michigan': 84, 'Minnesota': 59, 'Mississippi': 1, 'Missouri': 59, 'Nevada': 49, 'New Jersey': 277, 'New Mexico': 75, 'New York': 317, 'North Carolina': 110, 'North Dakota': 1, 'Ohio': 53, 'Oregon': 71, 'Pennsylvania': 179, 'Rhode Island': 28, 'South Carolina': 25, 'Tennessee': 46, 'Texas': 568, 'Utah': 27, 'Vermont': 24, 'Virginia': 243, 'Washington': 64, 'West Virginia': 6, 'Wisconsin': 33}, {'Alabama': 266, 'Alaska': 25, 'Arizona': 81, 'Arkansas': 216, 'California': 389, 'Colorado': 151, 'Connecticut': 112, 'Delaware': 43, 'Florida': 232, 'Georgia': 410, 'Idaho': 39, 'Illinois': 381, 'Indiana': 299, 'Iowa': 125, 'Kansas': 141, 'Kentucky': 291, 'Louisiana': 346, 'Maine': 50, 'Maryland': 98, 'Massachusetts': 133, 'Michigan': 216, 'Minnesota': 177, 'Mississippi': 249, 'Missouri': 207, 'Montana': 6, 'Nebraska': 90, 'Nevada': 30, 'New Hampshire': 92, 'New Jersey': 146, 'New Mexico': 154, 'New York': 348, 'North Carolina': 497, 'North Dakota': 54, 'Ohio': 412, 'Oklahoma': 176, 'Oregon': 136, 'Pennsylvania': 379, 'Rhode Island': 44, 'South Carolina': 364, 'South Dakota': 2, 'Tennessee': 374, 'Texas': 785, 'Utah': 101, 'Vermont': 71, 'Virginia': 372, 'Washington': 285, 'West Virginia': 104, 'Wisconsin': 229, 'Wyoming': 3}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 93, 1: 113, 2: 16, 3: 266}
# {0: 14, 1: 53, 3: 25}
# {0: 51, 1: 71, 2: 152, 3: 81}
# {0: 50, 1: 84, 2: 16, 3: 216}
# {0: 251, 1: 54, 2: 549, 3: 389}
# {0: 87, 1: 81, 2: 102, 3: 151}
# {0: 51, 1: 2, 2: 48, 3: 112}
# {0: 20, 1: 31, 2: 22, 3: 43}
# {0: 3, 2: 28}
# {0: 238, 1: 80, 2: 605, 3: 232}
# {0: 155, 1: 88, 2: 176, 3: 410}
# {0: 2, 2: 143}
# {0: 22, 1: 115, 2: 1, 3: 39}
# {0: 147, 1: 145, 2: 68, 3: 381}
# {0: 108, 1: 374, 2: 27, 3: 299}
# {0: 52, 1: 117, 2: 6, 3: 125}
# {0: 59, 1: 75, 3: 141}
# {0: 57, 1: 67, 2: 14, 3: 291}
# {0: 96, 1: 54, 2: 83, 3: 346}
# {0: 18, 1: 83, 3: 50}
# {0: 82, 1: 12, 2: 197, 3: 98}
# {0: 80, 1: 37, 2: 138, 3: 133}
# {0: 91, 1: 189, 2: 84, 3: 216}
# {0: 61, 1: 23, 2: 59, 3: 177}
# {0: 42, 1: 31, 2: 1, 3: 249}
# {0: 93, 1: 185, 2: 59, 3: 207}
# {0: 16, 1: 164, 3: 6}
# {0: 33, 1: 87, 3: 90}
# {0: 20, 1: 42, 2: 49, 3: 30}
# {0: 24, 1: 27, 3: 92}
# {0: 122, 1: 39, 2: 277, 3: 146}
# {0: 62, 1: 11, 2: 75, 3: 154}
# {0: 187, 1: 106, 2: 317, 3: 348}
# {0: 164, 1: 96, 2: 110, 3: 497}
# {0: 32, 1: 61, 2: 1, 3: 54}
# {0: 156, 1: 422, 2: 53, 3: 412}
# {0: 46, 1: 164, 3: 176}
# {0: 73, 1: 173, 2: 71, 3: 136}
# {0: 171, 1: 225, 2: 179, 3: 379}
# {0: 24, 1: 19, 2: 28, 3: 44}
# {0: 97, 1: 77, 2: 25, 3: 364}
# {0: 5, 1: 86, 3: 2}
# {0: 127, 1: 194, 2: 46, 3: 374}
# {0: 272, 1: 80, 2: 568, 3: 785}
# {0: 34, 1: 119, 2: 27, 3: 101}
# {0: 16, 1: 4, 2: 24, 3: 71}
# {0: 162, 1: 83, 2: 243, 3: 372}
# {0: 100, 1: 150, 2: 64, 3: 285}
# {0: 17, 1: 54, 2: 6, 3: 104}
# {0: 73, 1: 154, 2: 33, 3: 229}
# {0: 8, 1: 105, 3: 3}
# {'Alabama': 3, 'Alaska': 1, 'Arizona': 2, 'Arkansas': 3, 'California': 2, 'Colorado': 3, 'Connecticut': 3, 'Delaware': 3, 'District of Columbia': 2, 'Florida': 2, 'Georgia': 3, 'Hawaii': 2, 'Idaho': 1, 'Illinois': 3, 'Indiana': 1, 'Iowa': 3, 'Kansas': 3, 'Kentucky': 3, 'Louisiana': 3, 'Maine': 1, 'Maryland': 2, 'Massachusetts': 2, 'Michigan': 3, 'Minnesota': 3, 'Mississippi': 3, 'Missouri': 3, 'Montana': 1, 'Nebraska': 3, 'Nevada': 2, 'New Hampshire': 3, 'New Jersey': 2, 'New Mexico': 3, 'New York': 3, 'North Carolina': 3, 'North Dakota': 1, 'Ohio': 1, 'Oklahoma': 3, 'Oregon': 1, 'Pennsylvania': 3, 'Rhode Island': 3, 'South Carolina': 3, 'South Dakota': 1, 'Tennessee': 3, 'Texas': 3, 'Utah': 1, 'Vermont': 3, 'Virginia': 3, 'Washington': 3, 'West Virginia': 3, 'Wisconsin': 3, 'Wyoming': 1}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: ['Alaska', 'Idaho', 'Indiana', 'Maine', 'Montana', 'North Dakota', 'Ohio', 'Oregon', 'South Dakota', 'Utah', 'Wyoming'], 2: ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'Nevada', 'New Jersey'], 3: ['Alabama', 'Arkansas', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'New Mexico', 'New York', 'North Carolina', 'Oklahoma', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin'], 4: [], 0: []}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%15==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.820826  0.713125  0.084098  0.266282       3  Alabama
# 1    -0.192809  0.171376  0.242283 -0.100739       3  Alabama
# 2     0.005351  0.064978  0.405856  0.185879       3  Alabama
# 3    -1.895788  0.999090 -0.723363  0.438796       1  Alabama
# 4    -1.796077  0.730612 -0.856485  0.078101       1  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1575 -1.488246 -0.678402  0.364475  0.276722       1  Wyoming
# 1576 -2.811503 -1.402574 -0.160289 -0.052638       1  Wyoming
# 1577 -1.616034  0.535141  0.463260 -0.310619       1  Wyoming
# 1578 -2.316022 -1.554904 -1.035296 -0.577005       0  Wyoming
# 1579 -2.864733 -1.292380 -0.351881 -0.126298       1  Wyoming
#
# [1580 rows x 6 columns]>

# %%
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.820826  0.713125  0.084098  0.266282       3  Alabama
# 1    -0.192809  0.171376  0.242283 -0.100739       3  Alabama
# 2     0.005351  0.064978  0.405856  0.185879       3  Alabama
# 3    -1.895788  0.999090 -0.723363  0.438796       1  Alabama
# 4    -1.796077  0.730612 -0.856485  0.078101       1  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1575 -1.488246 -0.678402  0.364475  0.276722       1  Wyoming
# 1576 -2.811503 -1.402574 -0.160289 -0.052638       1  Wyoming
# 1577 -1.616034  0.535141  0.463260 -0.310619       1  Wyoming
# 1578 -2.316022 -1.554904 -1.035296 -0.577005       0  Wyoming
# 1579 -2.864733 -1.292380 -0.351881 -0.126298       1  Wyoming
#
# [1580 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([['Alaska', 'Idaho', 'Indiana', 'Maine', 'Montana', 'North Dakota', 'Ohio', 'Oregon', 'South Dakota', 'Utah', 'Wyoming'], ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'Nevada', 'New Jersey'], ['Alabama', 'Arkansas', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Nebraska', 'New Hampshire', 'New Mexico', 'New York', 'North Carolina', 'Oklahoma', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin'], [], []])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+6)*2

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers', hovertemplate="%{text}" +"<br>PC1: %{x}"+"<br>PC2: %{y}"+ "<br>PC3: %{z}<br> PC4(not normalized): %{marker.size:,}",
                    text=pca_2.State)

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("JULY Mobility KMeans.html")
                   )
# Out:
# 'JULY Mobility KMeans.html'
