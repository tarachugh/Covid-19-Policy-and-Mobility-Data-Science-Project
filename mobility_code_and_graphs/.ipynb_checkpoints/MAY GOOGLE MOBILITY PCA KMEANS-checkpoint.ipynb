# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-05")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794471                  US  United States          NaN            NaN
# 1794472                  US  United States          NaN            NaN
# 1794473                  US  United States          NaN            NaN
# 1794474                  US  United States          NaN            NaN
# 1794475                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332362                  US  United States      Wyoming  Weston County
# 2332363                  US  United States      Wyoming  Weston County
# 2332364                  US  United States      Wyoming  Weston County
# 2332365                  US  United States      Wyoming  Weston County
# 2332366                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794471        NaN             NaN               NaN  2020-05-01
# 1794472        NaN             NaN               NaN  2020-05-02
# 1794473        NaN             NaN               NaN  2020-05-03
# 1794474        NaN             NaN               NaN  2020-05-04
# 1794475        NaN             NaN               NaN  2020-05-05
# ...            ...             ...               ...         ...
# 2332362        NaN             NaN           56045.0  2020-05-25
# 2332363        NaN             NaN           56045.0  2020-05-26
# 2332364        NaN             NaN           56045.0  2020-05-27
# 2332365        NaN             NaN           56045.0  2020-05-28
# 2332366        NaN             NaN           56045.0  2020-05-29
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794471                                              -32.0
# 1794472                                              -34.0
# 1794473                                              -34.0
# 1794474                                              -29.0
# 1794475                                              -28.0
# ...                                                    ...
# 2332362                                                NaN
# 2332363                                                NaN
# 2332364                                                NaN
# 2332365                                                NaN
# 2332366                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794471                                               -7.0
# 1794472                                               -4.0
# 1794473                                               -8.0
# 1794474                                               -7.0
# 1794475                                               -3.0
# ...                                                    ...
# 2332362                                                NaN
# 2332363                                                NaN
# 2332364                                                NaN
# 2332365                                                NaN
# 2332366                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794471                                 7.0
# 1794472                                28.0
# 1794473                                22.0
# 1794474                                 5.0
# 1794475                                 5.0
# ...                                     ...
# 2332362                                 NaN
# 2332363                                 NaN
# 2332364                                 NaN
# 2332365                                 NaN
# 2332366                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794471                                          -43.0
# 1794472                                          -35.0
# 1794473                                          -40.0
# 1794474                                          -44.0
# 1794475                                          -43.0
# ...                                                ...
# 2332362                                            NaN
# 2332363                                            NaN
# 2332364                                            NaN
# 2332365                                            NaN
# 2332366                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794471                                    -45.0
# 1794472                                    -29.0
# 1794473                                    -31.0
# 1794474                                    -44.0
# 1794475                                    -45.0
# ...                                          ...
# 2332362                                    -62.0
# 2332363                                    -27.0
# 2332364                                    -26.0
# 2332365                                    -22.0
# 2332366                                    -24.0
#
#          residential_percent_change_from_baseline
# 1794471                                      18.0
# 1794472                                      10.0
# 1794473                                       8.0
# 1794474                                      16.0
# 1794475                                      17.0
# ...                                           ...
# 2332362                                       NaN
# 2332363                                       NaN
# 2332364                                       NaN
# 2332365                                       NaN
# 2332366                                       NaN
#
# [80716 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794471  United States          NaN  2020-05-01
# 1794472  United States          NaN  2020-05-02
# 1794473  United States          NaN  2020-05-03
# 1794474  United States          NaN  2020-05-04
# 1794475  United States          NaN  2020-05-05
# ...                ...          ...         ...
# 2332362  United States      Wyoming  2020-05-25
# 2332363  United States      Wyoming  2020-05-26
# 2332364  United States      Wyoming  2020-05-27
# 2332365  United States      Wyoming  2020-05-28
# 2332366  United States      Wyoming  2020-05-29
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794471                                              -32.0
# 1794472                                              -34.0
# 1794473                                              -34.0
# 1794474                                              -29.0
# 1794475                                              -28.0
# ...                                                    ...
# 2332362                                                NaN
# 2332363                                                NaN
# 2332364                                                NaN
# 2332365                                                NaN
# 2332366                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794471                                               -7.0
# 1794472                                               -4.0
# 1794473                                               -8.0
# 1794474                                               -7.0
# 1794475                                               -3.0
# ...                                                    ...
# 2332362                                                NaN
# 2332363                                                NaN
# 2332364                                                NaN
# 2332365                                                NaN
# 2332366                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794471                                          -43.0
# 1794472                                          -35.0
# 1794473                                          -40.0
# 1794474                                          -44.0
# 1794475                                          -43.0
# ...                                                ...
# 2332362                                            NaN
# 2332363                                            NaN
# 2332364                                            NaN
# 2332365                                            NaN
# 2332366                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794471                                    -45.0
# 1794472                                    -29.0
# 1794473                                    -31.0
# 1794474                                    -44.0
# 1794475                                    -45.0
# ...                                          ...
# 2332362                                    -62.0
# 2332363                                    -27.0
# 2332364                                    -26.0
# 2332365                                    -22.0
# 2332366                                    -24.0
#
#          residential_percent_change_from_baseline
# 1794471                                      18.0
# 1794472                                      10.0
# 1794473                                       8.0
# 1794474                                      16.0
# 1794475                                      17.0
# ...                                           ...
# 2332362                                       NaN
# 2332363                                       NaN
# 2332364                                       NaN
# 2332365                                       NaN
# 2332366                                       NaN
#
# [80716 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794674  United States      Alabama  2020-05-01
# 1794675  United States      Alabama  2020-05-02
# 1794676  United States      Alabama  2020-05-03
# 1794677  United States      Alabama  2020-05-04
# 1794678  United States      Alabama  2020-05-05
# ...                ...          ...         ...
# 2331610  United States      Wyoming  2020-05-07
# 2331611  United States      Wyoming  2020-05-08
# 2331616  United States      Wyoming  2020-05-13
# 2331618  United States      Wyoming  2020-05-15
# 2331623  United States      Wyoming  2020-05-20
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794674                                              -16.0
# 1794675                                              -21.0
# 1794676                                              -20.0
# 1794677                                              -11.0
# 1794678                                              -12.0
# ...                                                    ...
# 2331610                                              -12.0
# 2331611                                              -10.0
# 2331616                                               -7.0
# 2331618                                              -10.0
# 2331623                                                5.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794674                                                6.0
# 1794675                                                8.0
# 1794676                                                4.0
# 1794677                                                6.0
# 1794678                                                9.0
# ...                                                    ...
# 2331610                                                8.0
# 2331611                                               17.0
# 2331616                                                9.0
# 2331618                                               11.0
# 2331623                                               10.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794674                                          -17.0
# 1794675                                          -11.0
# 1794676                                          -18.0
# 1794677                                          -15.0
# 1794678                                          -14.0
# ...                                                ...
# 2331610                                           17.0
# 2331611                                           48.0
# 2331616                                           26.0
# 2331618                                           53.0
# 2331623                                           31.0
#
#          workplaces_percent_change_from_baseline  \
# 1794674                                    -36.0
# 1794675                                    -20.0
# 1794676                                    -27.0
# 1794677                                    -33.0
# 1794678                                    -33.0
# ...                                          ...
# 2331610                                    -28.0
# 2331611                                    -29.0
# 2331616                                    -27.0
# 2331618                                    -26.0
# 2331623                                    -26.0
#
#          residential_percent_change_from_baseline
# 1794674                                      13.0
# 1794675                                       6.0
# 1794676                                       6.0
# 1794677                                      11.0
# 1794678                                      12.0
# ...                                           ...
# 2331610                                       9.0
# 2331611                                       9.0
# 2331616                                       9.0
# 2331618                                       8.0
# 2331623                                       6.0
#
# [23269 rows x 8 columns]>

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794674  United States      Alabama  2020-05-01
# 1794675  United States      Alabama  2020-05-02
# 1794676  United States      Alabama  2020-05-03
# 1794677  United States      Alabama  2020-05-04
# 1794678  United States      Alabama  2020-05-05
# ...                ...          ...         ...
# 2331610  United States      Wyoming  2020-05-07
# 2331611  United States      Wyoming  2020-05-08
# 2331616  United States      Wyoming  2020-05-13
# 2331618  United States      Wyoming  2020-05-15
# 2331623  United States      Wyoming  2020-05-20
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794674                                           0.343286
# 1794675                                           0.016755
# 1794676                                           0.082061
# 1794677                                           0.669817
# 1794678                                           0.604511
# ...                                                    ...
# 2331610                                           0.604511
# 2331611                                           0.735123
# 2331616                                           0.931042
# 2331618                                           0.735123
# 2331623                                           1.714716
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794674                                           0.556105
# 1794675                                           0.732170
# 1794676                                           0.380041
# 1794677                                           0.556105
# 1794678                                           0.820202
# ...                                                    ...
# 2331610                                           0.732170
# 2331611                                           1.524458
# 2331616                                           0.820202
# 2331618                                           0.996266
# 2331623                                           0.908234
#
#          transit_stations_percent_change_from_baseline  \
# 1794674                                       0.153315
# 1794675                                       0.408483
# 1794676                                       0.110788
# 1794677                                       0.238371
# 1794678                                       0.280899
# ...                                                ...
# 2331610                                       1.599265
# 2331611                                       2.917631
# 2331616                                       1.982016
# 2331618                                       3.130270
# 2331623                                       2.194656
#
#          workplaces_percent_change_from_baseline  \
# 1794674                                -0.095396
# 1794675                                 1.142148
# 1794676                                 0.600723
# 1794677                                 0.136644
# 1794678                                 0.136644
# ...                                          ...
# 2331610                                 0.523376
# 2331611                                 0.446030
# 2331616                                 0.600723
# 2331618                                 0.678069
# 2331623                                 0.678069
#
#          residential_percent_change_from_baseline
# 1794674                                  0.130042
# 1794675                                 -1.106910
# 1794676                                 -1.106910
# 1794677                                 -0.223373
# 1794678                                 -0.046666
# ...                                           ...
# 2331610                                 -0.576788
# 2331611                                 -0.576788
# 2331616                                 -0.576788
# 2331618                                 -0.753495
# 2331623                                 -1.106910
#
# [23269 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.65284957 0.18047051 0.08407916 0.06163731]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0     -0.359170  0.519800 -0.256430  0.059909
# 1     -1.532515 -0.795667 -0.230993  0.444878
# 2     -1.039493 -0.676607 -0.237184  0.111696
# 3     -0.812211  0.373444 -0.226158 -0.181496
# 4     -0.832849  0.545203 -0.352313  0.020982
# ...         ...       ...       ...       ...
# 23264 -1.793366  0.453065  0.663205  0.451816
# 23265 -2.739831  1.277829  1.123898  1.226472
# 23266 -2.179566  0.698161  0.881048  0.380254
# 23267 -2.789080  0.924199  1.622311  1.044450
# 23268 -2.946906  0.820755  0.914926 -0.139637
#
# [23269 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline -0.447676  0.410668
# grocery_and_pharmacy_percent_change_from_baseline  -0.435112  0.377688
# transit_stations_percent_change_from_baseline      -0.437932  0.323105
# workplaces_percent_change_from_baseline            -0.440823 -0.593660
# residential_percent_change_from_baseline            0.473450  0.481534
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.039260 -0.790237
# grocery_and_pharmacy_percent_change_from_baseline  -0.656717  0.481572
# transit_stations_percent_change_from_baseline       0.749276  0.376463
# workplaces_percent_change_from_baseline             0.021832 -0.000132
# residential_percent_change_from_baseline            0.072732  0.043456

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: residential")
print("Greatest contributors to PC2: retail, residential, grocery, transit")

print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: grocery, transit")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: residential
# Greatest contributors to PC2: retail, residential, grocery, transit
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: grocery, transit

# %%
# # find OPTIMAL value for kmeans
# from sklearn.cluster import KMeans
# data_kmeans = pd.DataFrame(pca_data)
# Sum_of_squared_distances = []
# K = range(1,7)
# for k in K:
#     km = KMeans(n_clusters=k)
#     km = km.fit(pca_data)
#     Sum_of_squared_distances.append(km.inertia_)
# plt.plot(K, Sum_of_squared_distances, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Sum_of_squared_distances')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0     -0.359170  0.519800 -0.256430  0.059909        0
# 1     -1.532515 -0.795667 -0.230993  0.444878        2
# 2     -1.039493 -0.676607 -0.237184  0.111696        2
# 3     -0.812211  0.373444 -0.226158 -0.181496        0
# 4     -0.832849  0.545203 -0.352313  0.020982        0
# ...         ...       ...       ...       ...      ...
# 23264 -1.793366  0.453065  0.663205  0.451816        2
# 23265 -2.739831  1.277829  1.123898  1.226472        2
# 23266 -2.179566  0.698161  0.881048  0.380254        2
# 23267 -2.789080  0.924199  1.622311  1.044450        2
# 23268 -2.946906  0.820755  0.914926 -0.139637        2
#
# [23269 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0     -0.359170  0.519800 -0.256430  0.059909        0  Alabama
# 1     -1.532515 -0.795667 -0.230993  0.444878        2  Alabama
# 2     -1.039493 -0.676607 -0.237184  0.111696        2  Alabama
# 3     -0.812211  0.373444 -0.226158 -0.181496        0  Alabama
# 4     -0.832849  0.545203 -0.352313  0.020982        0  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 23264 -1.793366  0.453065  0.663205  0.451816        2  Wyoming
# 23265 -2.739831  1.277829  1.123898  1.226472        2  Wyoming
# 23266 -2.179566  0.698161  0.881048  0.380254        2  Wyoming
# 23267 -2.789080  0.924199  1.622311  1.044450        2  Wyoming
# 23268 -2.946906  0.820755  0.914926 -0.139637        2  Wyoming
#
# [23269 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([0, 2, 3, 1], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 114, 'Alaska': 28, 'Arizona': 125, 'Arkansas': 67, 'California': 258, 'Colorado': 140, 'Connecticut': 61, 'Delaware': 42, 'Florida': 229, 'Georgia': 281, 'Idaho': 39, 'Illinois': 314, 'Indiana': 352, 'Iowa': 122, 'Kansas': 104, 'Kentucky': 232, 'Louisiana': 195, 'Maine': 74, 'Maryland': 70, 'Massachusetts': 95, 'Michigan': 200, 'Minnesota': 170, 'Mississippi': 97, 'Missouri': 144, 'Montana': 22, 'Nebraska': 109, 'Nevada': 31, 'New Hampshire': 73, 'New Jersey': 64, 'New Mexico': 121, 'New York': 227, 'North Carolina': 328, 'North Dakota': 62, 'Ohio': 458, 'Oklahoma': 57, 'Oregon': 113, 'Pennsylvania': 292, 'Rhode Island': 44, 'South Carolina': 196, 'South Dakota': 25, 'Tennessee': 211, 'Texas': 629, 'Utah': 94, 'Vermont': 28, 'Virginia': 315, 'Washington': 273, 'West Virginia': 92, 'Wisconsin': 227, 'Wyoming': 24}, {'Alabama': 9, 'Alaska': 2, 'Arizona': 20, 'Arkansas': 9, 'California': 469, 'Colorado': 116, 'Connecticut': 86, 'Delaware': 36, 'District of Columbia': 28, 'Florida': 271, 'Georgia': 93, 'Hawaii': 128, 'Idaho': 3, 'Illinois': 153, 'Indiana': 25, 'Iowa': 21, 'Kansas': 11, 'Kentucky': 25, 'Louisiana': 53, 'Maine': 28, 'Maryland': 213, 'Massachusetts': 195, 'Michigan': 220, 'Minnesota': 62, 'Mississippi': 6, 'Missouri': 48, 'Montana': 4, 'Nebraska': 5, 'Nevada': 45, 'New Hampshire': 32, 'New Jersey': 381, 'New Mexico': 16, 'New York': 490, 'North Carolina': 110, 'North Dakota': 3, 'Ohio': 67, 'Oklahoma': 6, 'Oregon': 78, 'Pennsylvania': 299, 'Rhode Island': 58, 'South Carolina': 8, 'South Dakota': 1, 'Tennessee': 26, 'Texas': 143, 'Utah': 8, 'Vermont': 54, 'Virginia': 248, 'Washington': 92, 'West Virginia': 16, 'Wisconsin': 76}, {'Alabama': 339, 'Alaska': 48, 'Arizona': 102, 'Arkansas': 249, 'California': 138, 'Colorado': 89, 'Connecticut': 12, 'Delaware': 13, 'Florida': 186, 'Georgia': 331, 'Idaho': 129, 'Illinois': 142, 'Indiana': 348, 'Iowa': 118, 'Kansas': 129, 'Kentucky': 120, 'Louisiana': 249, 'Maine': 21, 'Maryland': 18, 'Massachusetts': 17, 'Michigan': 61, 'Minnesota': 31, 'Mississippi': 191, 'Missouri': 279, 'Montana': 124, 'Nebraska': 60, 'Nevada': 36, 'New Hampshire': 6, 'New Jersey': 13, 'New Mexico': 60, 'New York': 57, 'North Carolina': 322, 'North Dakota': 63, 'Ohio': 413, 'Oklahoma': 276, 'Oregon': 166, 'Pennsylvania': 141, 'Rhode Island': 1, 'South Carolina': 313, 'South Dakota': 63, 'Tennessee': 430, 'Texas': 644, 'Utah': 153, 'Virginia': 124, 'Washington': 139, 'West Virginia': 69, 'Wisconsin': 117, 'Wyoming': 94}, {'Alabama': 25, 'Alaska': 11, 'Arizona': 100, 'Arkansas': 16, 'California': 371, 'Colorado': 74, 'Connecticut': 57, 'Delaware': 27, 'District of Columbia': 3, 'Florida': 433, 'Georgia': 102, 'Hawaii': 16, 'Idaho': 7, 'Illinois': 106, 'Indiana': 43, 'Iowa': 18, 'Kansas': 21, 'Kentucky': 28, 'Louisiana': 72, 'Maine': 32, 'Maryland': 86, 'Massachusetts': 81, 'Michigan': 111, 'Minnesota': 62, 'Mississippi': 16, 'Missouri': 39, 'Montana': 36, 'Nebraska': 17, 'Nevada': 22, 'New Hampshire': 31, 'New Jersey': 142, 'New Mexico': 102, 'New York': 198, 'North Carolina': 130, 'North Dakota': 19, 'Ohio': 78, 'Oklahoma': 2, 'Oregon': 93, 'Pennsylvania': 205, 'Rhode Island': 29, 'South Carolina': 37, 'South Dakota': 4, 'Tennessee': 42, 'Texas': 262, 'Utah': 18, 'Vermont': 26, 'Virginia': 129, 'Washington': 90, 'West Virginia': 15, 'Wisconsin': 74, 'Wyoming': 3}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 114, 1: 9, 2: 339, 3: 25}
# {0: 28, 1: 2, 2: 48, 3: 11}
# {0: 125, 1: 20, 2: 102, 3: 100}
# {0: 67, 1: 9, 2: 249, 3: 16}
# {0: 258, 1: 469, 2: 138, 3: 371}
# {0: 140, 1: 116, 2: 89, 3: 74}
# {0: 61, 1: 86, 2: 12, 3: 57}
# {0: 42, 1: 36, 2: 13, 3: 27}
# {1: 28, 3: 3}
# {0: 229, 1: 271, 2: 186, 3: 433}
# {0: 281, 1: 93, 2: 331, 3: 102}
# {1: 128, 3: 16}
# {0: 39, 1: 3, 2: 129, 3: 7}
# {0: 314, 1: 153, 2: 142, 3: 106}
# {0: 352, 1: 25, 2: 348, 3: 43}
# {0: 122, 1: 21, 2: 118, 3: 18}
# {0: 104, 1: 11, 2: 129, 3: 21}
# {0: 232, 1: 25, 2: 120, 3: 28}
# {0: 195, 1: 53, 2: 249, 3: 72}
# {0: 74, 1: 28, 2: 21, 3: 32}
# {0: 70, 1: 213, 2: 18, 3: 86}
# {0: 95, 1: 195, 2: 17, 3: 81}
# {0: 200, 1: 220, 2: 61, 3: 111}
# {0: 170, 1: 62, 2: 31, 3: 62}
# {0: 97, 1: 6, 2: 191, 3: 16}
# {0: 144, 1: 48, 2: 279, 3: 39}
# {0: 22, 1: 4, 2: 124, 3: 36}
# {0: 109, 1: 5, 2: 60, 3: 17}
# {0: 31, 1: 45, 2: 36, 3: 22}
# {0: 73, 1: 32, 2: 6, 3: 31}
# {0: 64, 1: 381, 2: 13, 3: 142}
# {0: 121, 1: 16, 2: 60, 3: 102}
# {0: 227, 1: 490, 2: 57, 3: 198}
# {0: 328, 1: 110, 2: 322, 3: 130}
# {0: 62, 1: 3, 2: 63, 3: 19}
# {0: 458, 1: 67, 2: 413, 3: 78}
# {0: 57, 1: 6, 2: 276, 3: 2}
# {0: 113, 1: 78, 2: 166, 3: 93}
# {0: 292, 1: 299, 2: 141, 3: 205}
# {0: 44, 1: 58, 2: 1, 3: 29}
# {0: 196, 1: 8, 2: 313, 3: 37}
# {0: 25, 1: 1, 2: 63, 3: 4}
# {0: 211, 1: 26, 2: 430, 3: 42}
# {0: 629, 1: 143, 2: 644, 3: 262}
# {0: 94, 1: 8, 2: 153, 3: 18}
# {0: 28, 1: 54, 3: 26}
# {0: 315, 1: 248, 2: 124, 3: 129}
# {0: 273, 1: 92, 2: 139, 3: 90}
# {0: 92, 1: 16, 2: 69, 3: 15}
# {0: 227, 1: 76, 2: 117, 3: 74}
# {0: 24, 2: 94, 3: 3}
# {'Alabama': 2, 'Alaska': 2, 'Arizona': 0, 'Arkansas': 2, 'California': 1, 'Colorado': 0, 'Connecticut': 1, 'Delaware': 0, 'District of Columbia': 1, 'Florida': 3, 'Georgia': 2, 'Hawaii': 1, 'Idaho': 2, 'Illinois': 0, 'Indiana': 0, 'Iowa': 0, 'Kansas': 2, 'Kentucky': 0, 'Louisiana': 2, 'Maine': 0, 'Maryland': 1, 'Massachusetts': 1, 'Michigan': 1, 'Minnesota': 0, 'Mississippi': 2, 'Missouri': 2, 'Montana': 2, 'Nebraska': 0, 'Nevada': 1, 'New Hampshire': 0, 'New Jersey': 1, 'New Mexico': 0, 'New York': 1, 'North Carolina': 0, 'North Dakota': 2, 'Ohio': 0, 'Oklahoma': 2, 'Oregon': 2, 'Pennsylvania': 1, 'Rhode Island': 1, 'South Carolina': 2, 'South Dakota': 2, 'Tennessee': 2, 'Texas': 2, 'Utah': 2, 'Vermont': 1, 'Virginia': 0, 'Washington': 0, 'West Virginia': 0, 'Wisconsin': 0, 'Wyoming': 2}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: ['California', 'Connecticut', 'District of Columbia', 'Hawaii', 'Maryland', 'Massachusetts', 'Michigan', 'Nevada', 'New Jersey', 'New York', 'Pennsylvania', 'Rhode Island', 'Vermont'], 2: ['Alabama', 'Alaska', 'Arkansas', 'Georgia', 'Idaho', 'Kansas', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'North Dakota', 'Oklahoma', 'Oregon', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Wyoming'], 3: ['Florida'], 4: [], 0: ['Arizona', 'Colorado', 'Delaware', 'Illinois', 'Indiana', 'Iowa', 'Kentucky', 'Maine', 'Minnesota', 'Nebraska', 'New Hampshire', 'New Mexico', 'North Carolina', 'Ohio', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%15==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.359170  0.519800 -0.256430  0.059909       0  Alabama
# 1    -2.210203 -0.984251 -0.038893  0.231886       2  Alabama
# 2    -2.484740 -0.911986  0.329364 -0.100548       2  Alabama
# 3    -1.805481  0.366894 -0.210200 -0.126147       2  Alabama
# 4    -4.734054 -0.266076 -0.601543  0.205837       2  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1547 -0.245921  0.536603  0.391354  0.474193       0  Wyoming
# 1548 -1.771241  0.888384  0.419260  0.569845       2  Wyoming
# 1549 -0.725743 -0.070921 -0.111363 -0.363556       0  Wyoming
# 1550 -2.034673  0.501399 -0.313572 -0.409418       2  Wyoming
# 1551 -2.739831  1.277829  1.123898  1.226472       2  Wyoming
#
# [1552 rows x 6 columns]>

# %%
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.359170  0.519800 -0.256430  0.059909       0  Alabama
# 1    -2.210203 -0.984251 -0.038893  0.231886       2  Alabama
# 2    -2.484740 -0.911986  0.329364 -0.100548       2  Alabama
# 3    -1.805481  0.366894 -0.210200 -0.126147       2  Alabama
# 4    -4.734054 -0.266076 -0.601543  0.205837       2  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1547 -0.245921  0.536603  0.391354  0.474193       0  Wyoming
# 1548 -1.771241  0.888384  0.419260  0.569845       2  Wyoming
# 1549 -0.725743 -0.070921 -0.111363 -0.363556       0  Wyoming
# 1550 -2.034673  0.501399 -0.313572 -0.409418       2  Wyoming
# 1551 -2.739831  1.277829  1.123898  1.226472       2  Wyoming
#
# [1552 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([['California', 'Connecticut', 'District of Columbia', 'Hawaii', 'Maryland', 'Massachusetts', 'Michigan', 'Nevada', 'New Jersey', 'New York', 'Pennsylvania', 'Rhode Island', 'Vermont'], ['Alabama', 'Alaska', 'Arkansas', 'Georgia', 'Idaho', 'Kansas', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'North Dakota', 'Oklahoma', 'Oregon', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Wyoming'], ['Florida'], [], ['Arizona', 'Colorado', 'Delaware', 'Illinois', 'Indiana', 'Iowa', 'Kentucky', 'Maine', 'Minnesota', 'Nebraska', 'New Hampshire', 'New Mexico', 'North Carolina', 'Ohio', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+6)*2

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers', hovertemplate="%{text}" +"<br>PC1: %{x}"+"<br>PC2: %{y}"+ "<br>PC3: %{z}<br> PC4(not normalized): %{marker.size:,}",
                    text=pca_2.State)

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("MAY Mobility KMeans.html")
                   )
# Out:
# 'MAY Mobility KMeans.html'
