# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-04")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794441                  US  United States          NaN            NaN
# 1794442                  US  United States          NaN            NaN
# 1794443                  US  United States          NaN            NaN
# 1794444                  US  United States          NaN            NaN
# 1794445                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332341                  US  United States      Wyoming  Weston County
# 2332342                  US  United States      Wyoming  Weston County
# 2332343                  US  United States      Wyoming  Weston County
# 2332344                  US  United States      Wyoming  Weston County
# 2332345                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794441        NaN             NaN               NaN  2020-04-01
# 1794442        NaN             NaN               NaN  2020-04-02
# 1794443        NaN             NaN               NaN  2020-04-03
# 1794444        NaN             NaN               NaN  2020-04-04
# 1794445        NaN             NaN               NaN  2020-04-05
# ...            ...             ...               ...         ...
# 2332341        NaN             NaN           56045.0  2020-04-24
# 2332342        NaN             NaN           56045.0  2020-04-27
# 2332343        NaN             NaN           56045.0  2020-04-28
# 2332344        NaN             NaN           56045.0  2020-04-29
# 2332345        NaN             NaN           56045.0  2020-04-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794441                                              -37.0
# 1794442                                              -40.0
# 1794443                                              -42.0
# 1794444                                              -48.0
# 1794445                                              -49.0
# ...                                                    ...
# 2332341                                                NaN
# 2332342                                                NaN
# 2332343                                                NaN
# 2332344                                                NaN
# 2332345                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794441                                              -11.0
# 1794442                                              -11.0
# 1794443                                              -12.0
# 1794444                                              -15.0
# 1794445                                              -20.0
# ...                                                    ...
# 2332341                                                NaN
# 2332342                                                NaN
# 2332343                                                NaN
# 2332344                                                NaN
# 2332345                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794441                                -7.0
# 1794442                                -9.0
# 1794443                               -21.0
# 1794444                               -24.0
# 1794445                               -20.0
# ...                                     ...
# 2332341                                 NaN
# 2332342                                 NaN
# 2332343                                 NaN
# 2332344                                 NaN
# 2332345                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794441                                          -48.0
# 1794442                                          -51.0
# 1794443                                          -51.0
# 1794444                                          -50.0
# 1794445                                          -54.0
# ...                                                ...
# 2332341                                            NaN
# 2332342                                            NaN
# 2332343                                            NaN
# 2332344                                            NaN
# 2332345                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794441                                    -49.0
# 1794442                                    -50.0
# 1794443                                    -50.0
# 1794444                                    -37.0
# 1794445                                    -40.0
# ...                                          ...
# 2332341                                    -29.0
# 2332342                                    -35.0
# 2332343                                    -38.0
# 2332344                                    -42.0
# 2332345                                    -39.0
#
#          residential_percent_change_from_baseline
# 1794441                                      20.0
# 1794442                                      21.0
# 1794443                                      22.0
# 1794444                                      15.0
# 1794445                                      13.0
# ...                                           ...
# 2332341                                       NaN
# 2332342                                       NaN
# 2332343                                       NaN
# 2332344                                       NaN
# 2332345                                       NaN
#
# [80683 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data
# Out:
#         country_region sub_region_1        date  \
# 1794441  United States          NaN  2020-04-01
# 1794442  United States          NaN  2020-04-02
# 1794443  United States          NaN  2020-04-03
# 1794444  United States          NaN  2020-04-04
# 1794445  United States          NaN  2020-04-05
# ...                ...          ...         ...
# 2332341  United States      Wyoming  2020-04-24
# 2332342  United States      Wyoming  2020-04-27
# 2332343  United States      Wyoming  2020-04-28
# 2332344  United States      Wyoming  2020-04-29
# 2332345  United States      Wyoming  2020-04-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794441                                              -37.0
# 1794442                                              -40.0
# 1794443                                              -42.0
# 1794444                                              -48.0
# 1794445                                              -49.0
# ...                                                    ...
# 2332341                                                NaN
# 2332342                                                NaN
# 2332343                                                NaN
# 2332344                                                NaN
# 2332345                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794441                                              -11.0
# 1794442                                              -11.0
# 1794443                                              -12.0
# 1794444                                              -15.0
# 1794445                                              -20.0
# ...                                                    ...
# 2332341                                                NaN
# 2332342                                                NaN
# 2332343                                                NaN
# 2332344                                                NaN
# 2332345                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794441                                          -48.0
# 1794442                                          -51.0
# 1794443                                          -51.0
# 1794444                                          -50.0
# 1794445                                          -54.0
# ...                                                ...
# 2332341                                            NaN
# 2332342                                            NaN
# 2332343                                            NaN
# 2332344                                            NaN
# 2332345                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794441                                    -49.0
# 1794442                                    -50.0
# 1794443                                    -50.0
# 1794444                                    -37.0
# 1794445                                    -40.0
# ...                                          ...
# 2332341                                    -29.0
# 2332342                                    -35.0
# 2332343                                    -38.0
# 2332344                                    -42.0
# 2332345                                    -39.0
#
#          residential_percent_change_from_baseline
# 1794441                                      20.0
# 1794442                                      21.0
# 1794443                                      22.0
# 1794444                                      15.0
# 1794445                                      13.0
# ...                                           ...
# 2332341                                       NaN
# 2332342                                       NaN
# 2332343                                       NaN
# 2332344                                       NaN
# 2332345                                       NaN
#
# [80683 rows x 8 columns]

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-8-a41fd17ba840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how="any", inplace=True)

# %%
data
# Out:
#         country_region sub_region_1        date  \
# 1794644  United States      Alabama  2020-04-01
# 1794645  United States      Alabama  2020-04-02
# 1794646  United States      Alabama  2020-04-03
# 1794647  United States      Alabama  2020-04-04
# 1794648  United States      Alabama  2020-04-05
# ...                ...          ...         ...
# 2331596  United States      Wyoming  2020-04-23
# 2331597  United States      Wyoming  2020-04-24
# 2331600  United States      Wyoming  2020-04-27
# 2331602  United States      Wyoming  2020-04-29
# 2331603  United States      Wyoming  2020-04-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794644                                              -25.0
# 1794645                                              -32.0
# 1794646                                              -29.0
# 1794647                                              -41.0
# 1794648                                              -50.0
# ...                                                    ...
# 2331596                                              -27.0
# 2331597                                              -23.0
# 2331600                                              -18.0
# 2331602                                              -13.0
# 2331603                                              -16.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794644                                                5.0
# 1794645                                                3.0
# 1794646                                               12.0
# 1794647                                                8.0
# 1794648                                              -18.0
# ...                                                    ...
# 2331596                                                3.0
# 2331597                                                9.0
# 2331600                                               12.0
# 2331602                                               12.0
# 2331603                                                9.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794644                                          -20.0
# 1794645                                          -25.0
# 1794646                                          -29.0
# 1794647                                          -33.0
# 1794648                                          -40.0
# ...                                                ...
# 2331596                                           10.0
# 2331597                                           38.0
# 2331600                                            1.0
# 2331602                                           17.0
# 2331603                                           22.0
#
#          workplaces_percent_change_from_baseline  \
# 1794644                                    -39.0
# 1794645                                    -39.0
# 1794646                                    -40.0
# 1794647                                    -26.0
# 1794648                                    -36.0
# ...                                          ...
# 2331596                                    -34.0
# 2331597                                    -33.0
# 2331600                                    -30.0
# 2331602                                    -32.0
# 2331603                                    -34.0
#
#          residential_percent_change_from_baseline
# 1794644                                      14.0
# 1794645                                      16.0
# 1794646                                      16.0
# 1794647                                      11.0
# 1794648                                      12.0
# ...                                           ...
# 2331596                                      14.0
# 2331597                                      13.0
# 2331600                                      10.0
# 2331602                                      10.0
# 2331603                                      11.0
#
# [22912 rows x 8 columns]

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-10-a17db85ee869>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         country_region sub_region_1        date  \
# 1794644  United States      Alabama  2020-04-01
# 1794645  United States      Alabama  2020-04-02
# 1794646  United States      Alabama  2020-04-03
# 1794647  United States      Alabama  2020-04-04
# 1794648  United States      Alabama  2020-04-05
# ...                ...          ...         ...
# 2331596  United States      Wyoming  2020-04-23
# 2331597  United States      Wyoming  2020-04-24
# 2331600  United States      Wyoming  2020-04-27
# 2331602  United States      Wyoming  2020-04-29
# 2331603  United States      Wyoming  2020-04-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794644                                           0.926096
# 1794645                                           0.409316
# 1794646                                           0.630793
# 1794647                                          -0.255117
# 1794648                                          -0.919549
# ...                                                    ...
# 2331596                                           0.778445
# 2331597                                           1.073748
# 2331600                                           1.442877
# 2331602                                           1.812006
# 2331603                                           1.590528
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794644                                           1.414038
# 1794645                                           1.244713
# 1794646                                           2.006676
# 1794647                                           1.668026
# 1794648                                          -0.533202
# ...                                                    ...
# 2331596                                           1.244713
# 2331597                                           1.752688
# 2331600                                           2.006676
# 2331602                                           2.006676
# 2331603                                           1.752688
#
#          transit_stations_percent_change_from_baseline  \
# 1794644                                       0.705307
# 1794645                                       0.460784
# 1794646                                       0.265165
# 1794647                                       0.069547
# 1794648                                      -0.272785
# ...                                                ...
# 2331596                                       2.172446
# 2331597                                       3.541775
# 2331600                                       1.732304
# 2331602                                       2.514778
# 2331603                                       2.759301
#
#          workplaces_percent_change_from_baseline  \
# 1794644                                 0.508619
# 1794645                                 0.508619
# 1794646                                 0.404818
# 1794647                                 1.858038
# 1794648                                 0.820024
# ...                                          ...
# 2331596                                 1.027627
# 2331597                                 1.131428
# 2331600                                 1.442832
# 2331602                                 1.235229
# 2331603                                 1.027627
#
#          residential_percent_change_from_baseline
# 1794644                                 -0.581314
# 1794645                                 -0.214494
# 1794646                                 -0.214494
# 1794647                                 -1.131546
# 1794648                                 -0.948135
# ...                                           ...
# 2331596                                 -0.581314
# 2331597                                 -0.764725
# 2331600                                 -1.314956
# 2331602                                 -1.314956
# 2331603                                 -1.131546
#
# [22912 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.63457502 0.19166359 0.09037698 0.0560882 ]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0     -1.828957 -0.621101  0.390691  0.233721
# 1     -1.246429 -0.491666  0.421023  0.490210
# 2     -1.533568 -0.952083  1.008102  0.655105
# 3     -1.975854  0.837162  1.155200  1.201134
# 4     -0.031769  1.613107  0.031896  0.411420
# ...         ...       ...       ...       ...
# 22907 -2.579855 -0.566035 -0.855371  0.708931
# 22908 -3.666134 -1.090948 -1.640939  1.135860
# 22909 -3.531515 -0.464417  0.093111  0.473711
# 22910 -3.953306 -0.891774 -0.539171  0.390048
# 22911 -3.674656 -0.949274 -0.937382  0.491724
#
# [22912 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline -0.463777 -0.376942
# grocery_and_pharmacy_percent_change_from_baseline  -0.418845 -0.486327
# transit_stations_percent_change_from_baseline      -0.443075 -0.234707
# workplaces_percent_change_from_baseline            -0.462891  0.503675
# residential_percent_change_from_baseline            0.445978 -0.559129
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline  0.081857 -0.797409
# grocery_and_pharmacy_percent_change_from_baseline   0.552206  0.529015
# transit_stations_percent_change_from_baseline      -0.816959  0.284447
# workplaces_percent_change_from_baseline             0.111984  0.057269
# residential_percent_change_from_baseline           -0.091676  0.009633

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: residential")
print("Greatest contributors to PC2: workplace")
print("Greatest contributor to PC3: grocery")
print("Greatest contributors to PC4: grocery")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: residential
# Greatest contributors to PC2: workplace
# Greatest contributor to PC3: grocery
# Greatest contributors to PC4: grocery

# %%
# find OPTIMAL value for kmeans
from sklearn.cluster import KMeans
data_kmeans = pd.DataFrame(pca_data)
Sum_of_squared_distances = []
K = range(1,7)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(pca_data)
    Sum_of_squared_distances.append(km.inertia_)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0     -1.828957 -0.621101  0.390691  0.233721        3
# 1     -1.246429 -0.491666  0.421023  0.490210        3
# 2     -1.533568 -0.952083  1.008102  0.655105        3
# 3     -1.975854  0.837162  1.155200  1.201134        3
# 4     -0.031769  1.613107  0.031896  0.411420        1
# ...         ...       ...       ...       ...      ...
# 22907 -2.579855 -0.566035 -0.855371  0.708931        3
# 22908 -3.666134 -1.090948 -1.640939  1.135860        3
# 22909 -3.531515 -0.464417  0.093111  0.473711        3
# 22910 -3.953306 -0.891774 -0.539171  0.390048        3
# 22911 -3.674656 -0.949274 -0.937382  0.491724        3
#
# [22912 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0     -1.828957 -0.621101  0.390691  0.233721        3  Alabama
# 1     -1.246429 -0.491666  0.421023  0.490210        3  Alabama
# 2     -1.533568 -0.952083  1.008102  0.655105        3  Alabama
# 3     -1.975854  0.837162  1.155200  1.201134        3  Alabama
# 4     -0.031769  1.613107  0.031896  0.411420        1  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 22907 -2.579855 -0.566035 -0.855371  0.708931        3  Wyoming
# 22908 -3.666134 -1.090948 -1.640939  1.135860        3  Wyoming
# 22909 -3.531515 -0.464417  0.093111  0.473711        3  Wyoming
# 22910 -3.953306 -0.891774 -0.539171  0.390048        3  Wyoming
# 22911 -3.674656 -0.949274 -0.937382  0.491724        3  Wyoming
#
# [22912 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([3, 1, 0, 2], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 99, 'Alaska': 42, 'Arizona': 119, 'Arkansas': 40, 'California': 318, 'Colorado': 120, 'Connecticut': 84, 'Delaware': 54, 'Florida': 242, 'Georgia': 295, 'Idaho': 47, 'Illinois': 272, 'Indiana': 382, 'Iowa': 113, 'Kansas': 93, 'Kentucky': 217, 'Louisiana': 186, 'Maine': 67, 'Maryland': 111, 'Massachusetts': 96, 'Michigan': 139, 'Minnesota': 152, 'Mississippi': 104, 'Missouri': 178, 'Montana': 53, 'Nebraska': 78, 'Nevada': 42, 'New Hampshire': 83, 'New Jersey': 104, 'New Mexico': 120, 'New York': 317, 'North Carolina': 257, 'North Dakota': 66, 'Ohio': 467, 'Oklahoma': 63, 'Oregon': 116, 'Pennsylvania': 328, 'Rhode Island': 41, 'South Carolina': 163, 'South Dakota': 24, 'Tennessee': 205, 'Texas': 555, 'Utah': 98, 'Vermont': 22, 'Virginia': 310, 'Washington': 268, 'West Virginia': 85, 'Wisconsin': 275, 'Wyoming': 17}, {'Alabama': 46, 'Alaska': 20, 'Arizona': 99, 'Arkansas': 15, 'California': 327, 'Colorado': 67, 'Connecticut': 48, 'Delaware': 30, 'District of Columbia': 8, 'Florida': 469, 'Georgia': 112, 'Hawaii': 57, 'Idaho': 17, 'Illinois': 74, 'Indiana': 56, 'Iowa': 15, 'Kansas': 24, 'Kentucky': 22, 'Louisiana': 67, 'Maine': 39, 'Maryland': 82, 'Massachusetts': 76, 'Michigan': 120, 'Minnesota': 50, 'Mississippi': 23, 'Missouri': 45, 'Montana': 50, 'Nebraska': 10, 'Nevada': 19, 'New Hampshire': 29, 'New Jersey': 92, 'New Mexico': 35, 'New York': 165, 'North Carolina': 124, 'North Dakota': 28, 'Ohio': 96, 'Oklahoma': 13, 'Oregon': 65, 'Pennsylvania': 184, 'Rhode Island': 23, 'South Carolina': 64, 'South Dakota': 13, 'Tennessee': 57, 'Texas': 252, 'Utah': 21, 'Vermont': 16, 'Virginia': 85, 'Washington': 76, 'West Virginia': 23, 'Wisconsin': 87, 'Wyoming': 4}, {'Alabama': 6, 'Alaska': 1, 'Arizona': 2, 'Arkansas': 1, 'California': 302, 'Colorado': 148, 'Connecticut': 78, 'Delaware': 21, 'District of Columbia': 22, 'Florida': 211, 'Georgia': 70, 'Hawaii': 84, 'Idaho': 3, 'Illinois': 101, 'Indiana': 31, 'Iowa': 16, 'Kansas': 15, 'Kentucky': 10, 'Louisiana': 47, 'Maine': 31, 'Maryland': 202, 'Massachusetts': 196, 'Michigan': 304, 'Minnesota': 83, 'Mississippi': 2, 'Missouri': 37, 'Montana': 9, 'Nebraska': 2, 'Nevada': 34, 'New Hampshire': 34, 'New Jersey': 388, 'New Mexico': 3, 'New York': 443, 'North Carolina': 89, 'North Dakota': 5, 'Ohio': 53, 'Oregon': 59, 'Pennsylvania': 301, 'Rhode Island': 69, 'South Carolina': 8, 'South Dakota': 1, 'Tennessee': 29, 'Texas': 136, 'Utah': 4, 'Vermont': 60, 'Virginia': 170, 'Washington': 64, 'West Virginia': 19, 'Wisconsin': 57, 'Wyoming': 1}, {'Alabama': 322, 'Alaska': 21, 'Arizona': 123, 'Arkansas': 281, 'California': 259, 'Colorado': 76, 'Connecticut': 7, 'Delaware': 13, 'Florida': 174, 'Georgia': 295, 'Idaho': 111, 'Illinois': 239, 'Indiana': 259, 'Iowa': 148, 'Kansas': 127, 'Kentucky': 151, 'Louisiana': 227, 'Maine': 13, 'Maryland': 12, 'Massachusetts': 3, 'Michigan': 22, 'Minnesota': 41, 'Mississippi': 191, 'Missouri': 259, 'Montana': 64, 'Nebraska': 94, 'Nevada': 45, 'New Jersey': 21, 'New Mexico': 157, 'New York': 46, 'North Carolina': 432, 'North Dakota': 54, 'Ohio': 364, 'Oklahoma': 254, 'Oregon': 188, 'Pennsylvania': 104, 'South Carolina': 313, 'South Dakota': 54, 'Tennessee': 386, 'Texas': 697, 'Utah': 150, 'Virginia': 226, 'Washington': 185, 'West Virginia': 72, 'Wisconsin': 98, 'Wyoming': 106}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
#         print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
# print(states_clusters)

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: ['California', 'Florida'], 2: ['Colorado', 'District of Columbia', 'Hawaii', 'Maryland', 'Massachusetts', 'Michigan', 'New Jersey', 'New York', 'Rhode Island', 'Vermont'], 3: ['Alabama', 'Arizona', 'Arkansas', 'Idaho', 'Iowa', 'Kansas', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Mexico', 'North Carolina', 'Oklahoma', 'Oregon', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Wyoming'], 4: [], 0: ['Alaska', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Indiana', 'Kentucky', 'Maine', 'Minnesota', 'New Hampshire', 'North Dakota', 'Ohio', 'Pennsylvania', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%50==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of          PC 1      PC 2      PC 3      PC 4 Cluster      State
# 0   -1.828957 -0.621101  0.390691  0.233721       3    Alabama
# 1   -1.088034  0.737813 -0.453996  0.097115       3    Alabama
# 2   -3.129177 -0.054437 -0.456475 -0.467775       3    Alabama
# 3   -3.329382  0.796199  0.158806 -0.241527       3    Alabama
# 4   -0.180702 -0.066816  0.126059  0.099895       0    Alabama
# ..        ...       ...       ...       ...     ...        ...
# 454  0.015601 -0.894998 -1.088136 -0.289909       0  Wisconsin
# 455  1.053624 -0.834547 -0.766630  0.405786       0  Wisconsin
# 456 -1.313474 -0.006023 -0.783932  0.279599       3    Wyoming
# 457 -2.012352  1.282097 -0.563768  0.381457       3    Wyoming
# 458 -1.628274  0.306631 -1.111951  0.458536       3    Wyoming
#
# [459 rows x 6 columns]>

# %%
pca_2
# Out:
#          PC 1      PC 2      PC 3      PC 4 Cluster      State
# 0   -1.828957 -0.621101  0.390691  0.233721       3    Alabama
# 1   -1.088034  0.737813 -0.453996  0.097115       3    Alabama
# 2   -3.129177 -0.054437 -0.456475 -0.467775       3    Alabama
# 3   -3.329382  0.796199  0.158806 -0.241527       3    Alabama
# 4   -0.180702 -0.066816  0.126059  0.099895       0    Alabama
# ..        ...       ...       ...       ...     ...        ...
# 454  0.015601 -0.894998 -1.088136 -0.289909       0  Wisconsin
# 455  1.053624 -0.834547 -0.766630  0.405786       0  Wisconsin
# 456 -1.313474 -0.006023 -0.783932  0.279599       3    Wyoming
# 457 -2.012352  1.282097 -0.563768  0.381457       3    Wyoming
# 458 -1.628274  0.306631 -1.111951  0.458536       3    Wyoming
#
# [459 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([['California', 'Florida'], ['Colorado', 'District of Columbia', 'Hawaii', 'Maryland', 'Massachusetts', 'Michigan', 'New Jersey', 'New York', 'Rhode Island', 'Vermont'], ['Alabama', 'Arizona', 'Arkansas', 'Idaho', 'Iowa', 'Kansas', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Mexico', 'North Carolina', 'Oklahoma', 'Oregon', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Wyoming'], [], ['Alaska', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Indiana', 'Kentucky', 'Maine', 'Minnesota', 'New Hampshire', 'North Dakota', 'Ohio', 'Pennsylvania', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+5)*3

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers', hovertemplate="%{text}" +"<br>PC1: %{x}"+"<br>PC2: %{y}"+ "<br>PC3: %{z}<br> PC4(not normalized): %{marker.size:,}",
                    text=pca_2.State)

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("April Mobility KMeans.html")
                   )
# Out:
# 'April Mobility KMeans.html'
