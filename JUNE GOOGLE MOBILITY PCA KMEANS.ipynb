# %%
import numpy as np
import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler




data=pd.read_csv("/Users/Tara/Downloads/Global_Mobility_Report (1).csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning:
#
# Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code        country_region       sub_region_1  \
# 0                        AE  United Arab Emirates                NaN
# 1                        AE  United Arab Emirates                NaN
# 2                        AE  United Arab Emirates                NaN
# 3                        AE  United Arab Emirates                NaN
# 4                        AE  United Arab Emirates                NaN
# ...                     ...                   ...                ...
# 2356279                  ZW              Zimbabwe  Midlands Province
# 2356280                  ZW              Zimbabwe  Midlands Province
# 2356281                  ZW              Zimbabwe  Midlands Province
# 2356282                  ZW              Zimbabwe  Midlands Province
# 2356283                  ZW              Zimbabwe  Midlands Province
#
#         sub_region_2 metro_area iso_3166_2_code  census_fips_code        date  \
# 0                NaN        NaN             NaN               NaN  2020-02-15
# 1                NaN        NaN             NaN               NaN  2020-02-16
# 2                NaN        NaN             NaN               NaN  2020-02-17
# 3                NaN        NaN             NaN               NaN  2020-02-18
# 4                NaN        NaN             NaN               NaN  2020-02-19
# ...              ...        ...             ...               ...         ...
# 2356279       Kwekwe        NaN             NaN               NaN  2020-08-31
# 2356280       Kwekwe        NaN             NaN               NaN  2020-09-01
# 2356281       Kwekwe        NaN             NaN               NaN  2020-09-02
# 2356282       Kwekwe        NaN             NaN               NaN  2020-09-03
# 2356283       Kwekwe        NaN             NaN               NaN  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 0                                                      0.0
# 1                                                      1.0
# 2                                                     -1.0
# 3                                                     -2.0
# 4                                                     -2.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                      4.0
# 1                                                      4.0
# 2                                                      1.0
# 3                                                      1.0
# 4                                                      0.0
# ...                                                    ...
# 2356279                                                NaN
# 2356280                                                NaN
# 2356281                                                NaN
# 2356282                                                NaN
# 2356283                                                NaN
#
#          parks_percent_change_from_baseline  \
# 0                                       5.0
# 1                                       4.0
# 2                                       5.0
# 3                                       5.0
# 4                                       4.0
# ...                                     ...
# 2356279                                 NaN
# 2356280                                 NaN
# 2356281                                 NaN
# 2356282                                 NaN
# 2356283                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 0                                                  0.0
# 1                                                  1.0
# 2                                                  1.0
# 3                                                  0.0
# 4                                                 -1.0
# ...                                                ...
# 2356279                                            NaN
# 2356280                                            NaN
# 2356281                                            NaN
# 2356282                                            NaN
# 2356283                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 0                                            2.0
# 1                                            2.0
# 2                                            2.0
# 3                                            2.0
# 4                                            2.0
# ...                                          ...
# 2356279                                     -1.0
# 2356280                                     -2.0
# 2356281                                      5.0
# 2356282                                      6.0
# 2356283                                      2.0
#
#          residential_percent_change_from_baseline
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 2356279                                       NaN
# 2356280                                       NaN
# 2356281                                       NaN
# 2356282                                       NaN
# 2356283                                       NaN
#
# [2356284 rows x 14 columns]>

# %%
data=data[data.country_region=="United States"]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region_code country_region sub_region_1   sub_region_2  \
# 1794395                  US  United States          NaN            NaN
# 1794396                  US  United States          NaN            NaN
# 1794397                  US  United States          NaN            NaN
# 1794398                  US  United States          NaN            NaN
# 1794399                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332432                  US  United States      Wyoming  Weston County
# 2332433                  US  United States      Wyoming  Weston County
# 2332434                  US  United States      Wyoming  Weston County
# 2332435                  US  United States      Wyoming  Weston County
# 2332436                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794395        NaN             NaN               NaN  2020-02-15
# 1794396        NaN             NaN               NaN  2020-02-16
# 1794397        NaN             NaN               NaN  2020-02-17
# 1794398        NaN             NaN               NaN  2020-02-18
# 1794399        NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 2332432        NaN             NaN           56045.0  2020-08-31
# 2332433        NaN             NaN           56045.0  2020-09-01
# 2332434        NaN             NaN           56045.0  2020-09-02
# 2332435        NaN             NaN           56045.0  2020-09-03
# 2332436        NaN             NaN           56045.0  2020-09-04
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794395                                                6.0
# 1794396                                                7.0
# 1794397                                                6.0
# 1794398                                                0.0
# 1794399                                                2.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794395                                                2.0
# 1794396                                                1.0
# 1794397                                                0.0
# 1794398                                               -1.0
# 1794399                                                0.0
# ...                                                    ...
# 2332432                                                NaN
# 2332433                                                NaN
# 2332434                                                NaN
# 2332435                                                NaN
# 2332436                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794395                                15.0
# 1794396                                16.0
# 1794397                                28.0
# 1794398                                 6.0
# 1794399                                 8.0
# ...                                     ...
# 2332432                                 NaN
# 2332433                                 NaN
# 2332434                                 NaN
# 2332435                                 NaN
# 2332436                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794395                                            3.0
# 1794396                                            2.0
# 1794397                                           -9.0
# 1794398                                            1.0
# 1794399                                            1.0
# ...                                                ...
# 2332432                                            NaN
# 2332433                                            NaN
# 2332434                                            NaN
# 2332435                                            NaN
# 2332436                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794395                                      2.0
# 1794396                                      0.0
# 1794397                                    -24.0
# 1794398                                      0.0
# 1794399                                      1.0
# ...                                          ...
# 2332432                                    -21.0
# 2332433                                    -20.0
# 2332434                                    -20.0
# 2332435                                    -12.0
# 2332436                                     -7.0
#
#          residential_percent_change_from_baseline
# 1794395                                      -1.0
# 1794396                                      -1.0
# 1794397                                       5.0
# 1794398                                       1.0
# 1794399                                       0.0
# ...                                           ...
# 2332432                                       NaN
# 2332433                                       NaN
# 2332434                                       NaN
# 2332435                                       NaN
# 2332436                                       NaN
#
# [538042 rows x 14 columns]>

# %%
data=data[data.date.astype(str).str.contains("2020-06")]
data
# Out:
#         country_region_code country_region sub_region_1   sub_region_2  \
# 1794502                  US  United States          NaN            NaN
# 1794503                  US  United States          NaN            NaN
# 1794504                  US  United States          NaN            NaN
# 1794505                  US  United States          NaN            NaN
# 1794506                  US  United States          NaN            NaN
# ...                     ...            ...          ...            ...
# 2332384                  US  United States      Wyoming  Weston County
# 2332385                  US  United States      Wyoming  Weston County
# 2332386                  US  United States      Wyoming  Weston County
# 2332387                  US  United States      Wyoming  Weston County
# 2332388                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 1794502        NaN             NaN               NaN  2020-06-01
# 1794503        NaN             NaN               NaN  2020-06-02
# 1794504        NaN             NaN               NaN  2020-06-03
# 1794505        NaN             NaN               NaN  2020-06-04
# 1794506        NaN             NaN               NaN  2020-06-05
# ...            ...             ...               ...         ...
# 2332384        NaN             NaN           56045.0  2020-06-24
# 2332385        NaN             NaN           56045.0  2020-06-25
# 2332386        NaN             NaN           56045.0  2020-06-26
# 2332387        NaN             NaN           56045.0  2020-06-29
# 2332388        NaN             NaN           56045.0  2020-06-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794502                                              -18.0
# 1794503                                              -18.0
# 1794504                                              -16.0
# 1794505                                              -18.0
# 1794506                                              -20.0
# ...                                                    ...
# 2332384                                                NaN
# 2332385                                                NaN
# 2332386                                                NaN
# 2332387                                                NaN
# 2332388                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794502                                               -2.0
# 1794503                                                0.0
# 1794504                                                1.0
# 1794505                                                1.0
# 1794506                                               -2.0
# ...                                                    ...
# 2332384                                                NaN
# 2332385                                                NaN
# 2332386                                                NaN
# 2332387                                                NaN
# 2332388                                                NaN
#
#          parks_percent_change_from_baseline  \
# 1794502                                28.0
# 1794503                                35.0
# 1794504                                33.0
# 1794505                                40.0
# 1794506                                34.0
# ...                                     ...
# 2332384                                 NaN
# 2332385                                 NaN
# 2332386                                 NaN
# 2332387                                 NaN
# 2332388                                 NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794502                                          -36.0
# 1794503                                          -36.0
# 1794504                                          -35.0
# 1794505                                          -35.0
# 1794506                                          -34.0
# ...                                                ...
# 2332384                                            NaN
# 2332385                                            NaN
# 2332386                                            NaN
# 2332387                                            NaN
# 2332388                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794502                                    -37.0
# 1794503                                    -37.0
# 1794504                                    -37.0
# 1794505                                    -37.0
# 1794506                                    -36.0
# ...                                          ...
# 2332384                                    -28.0
# 2332385                                    -20.0
# 2332386                                    -22.0
# 2332387                                    -25.0
# 2332388                                    -14.0
#
#          residential_percent_change_from_baseline
# 1794502                                      12.0
# 1794503                                      13.0
# 1794504                                      13.0
# 1794505                                      13.0
# 1794506                                      13.0
# ...                                           ...
# 2332384                                       NaN
# 2332385                                       NaN
# 2332386                                       NaN
# 2332387                                       NaN
# 2332388                                       NaN
#
# [78688 rows x 14 columns]

# %%
data=data[["country_region", "sub_region_1", "date", 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline', 'transit_stations_percent_change_from_baseline', "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794502  United States          NaN  2020-06-01
# 1794503  United States          NaN  2020-06-02
# 1794504  United States          NaN  2020-06-03
# 1794505  United States          NaN  2020-06-04
# 1794506  United States          NaN  2020-06-05
# ...                ...          ...         ...
# 2332384  United States      Wyoming  2020-06-24
# 2332385  United States      Wyoming  2020-06-25
# 2332386  United States      Wyoming  2020-06-26
# 2332387  United States      Wyoming  2020-06-29
# 2332388  United States      Wyoming  2020-06-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794502                                              -18.0
# 1794503                                              -18.0
# 1794504                                              -16.0
# 1794505                                              -18.0
# 1794506                                              -20.0
# ...                                                    ...
# 2332384                                                NaN
# 2332385                                                NaN
# 2332386                                                NaN
# 2332387                                                NaN
# 2332388                                                NaN
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794502                                               -2.0
# 1794503                                                0.0
# 1794504                                                1.0
# 1794505                                                1.0
# 1794506                                               -2.0
# ...                                                    ...
# 2332384                                                NaN
# 2332385                                                NaN
# 2332386                                                NaN
# 2332387                                                NaN
# 2332388                                                NaN
#
#          transit_stations_percent_change_from_baseline  \
# 1794502                                          -36.0
# 1794503                                          -36.0
# 1794504                                          -35.0
# 1794505                                          -35.0
# 1794506                                          -34.0
# ...                                                ...
# 2332384                                            NaN
# 2332385                                            NaN
# 2332386                                            NaN
# 2332387                                            NaN
# 2332388                                            NaN
#
#          workplaces_percent_change_from_baseline  \
# 1794502                                    -37.0
# 1794503                                    -37.0
# 1794504                                    -37.0
# 1794505                                    -37.0
# 1794506                                    -36.0
# ...                                          ...
# 2332384                                    -28.0
# 2332385                                    -20.0
# 2332386                                    -22.0
# 2332387                                    -25.0
# 2332388                                    -14.0
#
#          residential_percent_change_from_baseline
# 1794502                                      12.0
# 1794503                                      13.0
# 1794504                                      13.0
# 1794505                                      13.0
# 1794506                                      13.0
# ...                                           ...
# 2332384                                       NaN
# 2332385                                       NaN
# 2332386                                       NaN
# 2332387                                       NaN
# 2332388                                       NaN
#
# [78688 rows x 8 columns]>

# %%
data.dropna(axis=0, how="any", inplace=True)
# Out:
# <ipython-input-76-a41fd17ba840>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head
# Out:
# <bound method NDFrame.head of         country_region sub_region_1        date  \
# 1794705  United States      Alabama  2020-06-01
# 1794706  United States      Alabama  2020-06-02
# 1794707  United States      Alabama  2020-06-03
# 1794708  United States      Alabama  2020-06-04
# 1794709  United States      Alabama  2020-06-05
# ...                ...          ...         ...
# 2330736  United States      Wyoming  2020-06-26
# 2330737  United States      Wyoming  2020-06-27
# 2330738  United States      Wyoming  2020-06-28
# 2330739  United States      Wyoming  2020-06-29
# 2330740  United States      Wyoming  2020-06-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794705                                               -1.0
# 1794706                                               -4.0
# 1794707                                                1.0
# 1794708                                               -6.0
# 1794709                                              -10.0
# ...                                                    ...
# 2330736                                               -2.0
# 2330737                                               -5.0
# 2330738                                                3.0
# 2330739                                               12.0
# 2330740                                               10.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794705                                                8.0
# 1794706                                                7.0
# 1794707                                                9.0
# 1794708                                                8.0
# 1794709                                                2.0
# ...                                                    ...
# 2330736                                               21.0
# 2330737                                               18.0
# 2330738                                               11.0
# 2330739                                               20.0
# 2330740                                               21.0
#
#          transit_stations_percent_change_from_baseline  \
# 1794705                                           -1.0
# 1794706                                           -3.0
# 1794707                                           -1.0
# 1794708                                           -4.0
# 1794709                                           -5.0
# ...                                                ...
# 2330736                                            8.0
# 2330737                                            7.0
# 2330738                                           -2.0
# 2330739                                           11.0
# 2330740                                           -4.0
#
#          workplaces_percent_change_from_baseline  \
# 1794705                                    -28.0
# 1794706                                    -27.0
# 1794707                                    -28.0
# 1794708                                    -27.0
# 1794709                                    -28.0
# ...                                          ...
# 2330736                                    -26.0
# 2330737                                    -10.0
# 2330738                                     -8.0
# 2330739                                    -23.0
# 2330740                                    -23.0
#
#          residential_percent_change_from_baseline
# 1794705                                       8.0
# 1794706                                       9.0
# 1794707                                       8.0
# 1794708                                       9.0
# 1794709                                      10.0
# ...                                           ...
# 2330736                                       4.0
# 2330737                                      -3.0
# 2330738                                      -2.0
# 2330739                                       3.0
# 2330740                                       5.0
#
# [23046 rows x 8 columns]>

# %%
scaler=StandardScaler()
data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]=scaler.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]) 

data
# Out:
# <ipython-input-78-a17db85ee869>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1736: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         country_region sub_region_1        date  \
# 1794705  United States      Alabama  2020-06-01
# 1794706  United States      Alabama  2020-06-02
# 1794707  United States      Alabama  2020-06-03
# 1794708  United States      Alabama  2020-06-04
# 1794709  United States      Alabama  2020-06-05
# ...                ...          ...         ...
# 2330736  United States      Wyoming  2020-06-26
# 2330737  United States      Wyoming  2020-06-27
# 2330738  United States      Wyoming  2020-06-28
# 2330739  United States      Wyoming  2020-06-29
# 2330740  United States      Wyoming  2020-06-30
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1794705                                           0.566915
# 1794706                                           0.358397
# 1794707                                           0.705927
# 1794708                                           0.219385
# 1794709                                          -0.058640
# ...                                                    ...
# 2330736                                           0.497409
# 2330737                                           0.288891
# 2330738                                           0.844940
# 2330739                                           1.470494
# 2330740                                           1.331482
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1794705                                           0.377226
# 1794706                                           0.285928
# 1794707                                           0.468524
# 1794708                                           0.377226
# 1794709                                          -0.170560
# ...                                                    ...
# 2330736                                           1.564097
# 2330737                                           1.290204
# 2330738                                           0.651120
# 2330739                                           1.472799
# 2330740                                           1.564097
#
#          transit_stations_percent_change_from_baseline  \
# 1794705                                       0.313974
# 1794706                                       0.233672
# 1794707                                       0.313974
# 1794708                                       0.193520
# 1794709                                       0.153369
# ...                                                ...
# 2330736                                       0.675338
# 2330737                                       0.635186
# 2330738                                       0.273823
# 2330739                                       0.795792
# 2330740                                       0.193520
#
#          workplaces_percent_change_from_baseline  \
# 1794705                                 0.006464
# 1794706                                 0.093529
# 1794707                                 0.006464
# 1794708                                 0.093529
# 1794709                                 0.006464
# ...                                          ...
# 2330736                                 0.180593
# 2330737                                 1.573627
# 2330738                                 1.747756
# 2330739                                 0.441787
# 2330740                                 0.441787
#
#          residential_percent_change_from_baseline
# 1794705                                 -0.046697
# 1794706                                  0.164029
# 1794707                                 -0.046697
# 1794708                                  0.164029
# 1794709                                  0.374755
# ...                                           ...
# 2330736                                 -0.889602
# 2330737                                 -2.364685
# 2330738                                 -2.153959
# 2330739                                 -1.100328
# 2330740                                 -0.678876
#
# [23046 rows x 8 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=4)
principal_components = pca.fit_transform(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]])
pca_data = pd.DataFrame(data = principal_components, columns = ['PC 1', 'PC 2', "PC 3", "PC 4"])
print(pca.explained_variance_ratio_)
print("0.98260139 of the variance in the data is represented by these 4 principle components")
pca_data
# Out:
# [0.62514629 0.21285298 0.0884521  0.05880458]
# 0.98260139 of the variance in the data is represented by these 4 principle components
#            PC 1      PC 2      PC 3      PC 4
# 0     -0.579347 -0.456826 -0.001628 -0.126707
# 1     -0.346065 -0.347553  0.011748 -0.019703
# 2     -0.679869 -0.557805 -0.060786 -0.184415
# 3     -0.305198 -0.315638 -0.069763  0.120475
# 4      0.209230 -0.096465  0.264593  0.050267
# ...         ...       ...       ...       ...
# 23041 -1.702067 -0.528073 -0.526839  0.592081
# 23042 -2.785450  1.198830 -0.662810  0.450687
# 23043 -2.567795  1.313459 -0.577759 -0.413684
# 23044 -2.362630 -0.696386 -0.454437 -0.175155
# 23045 -1.862521 -0.730345 -0.934917 -0.187258
#
# [23046 rows x 4 columns]

# %%
# factor loadings are correlations of features and components- trying to find the latent factors

loadings = pd.DataFrame( pca.components_, columns=["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]).T
loadings
# Out:
#                                                            0         1  \
# retail_and_recreation_percent_change_from_baseline -0.443322 -0.446900
# grocery_and_pharmacy_percent_change_from_baseline  -0.426023 -0.425582
# transit_stations_percent_change_from_baseline      -0.451679 -0.215318
# workplaces_percent_change_from_baseline            -0.424931  0.613284
# residential_percent_change_from_baseline            0.487227 -0.443488
#
#                                                            2         3
# retail_and_recreation_percent_change_from_baseline -0.033719 -0.762858
# grocery_and_pharmacy_percent_change_from_baseline  -0.596626  0.529468
# transit_stations_percent_change_from_baseline       0.790193  0.353863
# workplaces_percent_change_from_baseline            -0.083585  0.015776
# residential_percent_change_from_baseline            0.107282  0.110648

# %%
print("'loadings' are also eigenvectors")
print("Greatest contributors to PC1: residential")
print("Greatest contributors to PC2: workplace")

print("Greatest contributor to PC3: transit")
print("Greatest contributors to PC4: grocery and transit")

# https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# could also do color matrix https://towardsdatascience.com/understand-your-data-with-principle-component-analysis-pca-and-discover-underlying-patterns-d6cadb020939
# Out:
# 'loadings' are also eigenvectors
# Greatest contributors to PC1: residential
# Greatest contributors to PC2: workplace
# Greatest contributor to PC3: transit
# Greatest contributors to PC4: grocery and transit

# %%
# # find OPTIMAL value for kmeans
# from sklearn.cluster import KMeans
# data_kmeans = pd.DataFrame(pca_data)
# Sum_of_squared_distances = []
# K = range(1,7)
# for k in K:
#     km = KMeans(n_clusters=k)
#     km = km.fit(pca_data)
#     Sum_of_squared_distances.append(km.inertia_)
# plt.plot(K, Sum_of_squared_distances, 'bx-')
# plt.xlabel('k')
# plt.ylabel('Sum_of_squared_distances')
# plt.title('Elbow Method For Optimal k')
# plt.show()

# %%
print(type(data[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# run KMeans
kmeans = KMeans(n_clusters=4)
y = kmeans.fit_predict(pca_data[['PC 1', 'PC 2', "PC 3", "PC 4"]])
pca_data['Cluster'] = y
# pca_data["State"]=data["sub_region_1"]
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster
# 0     -0.579347 -0.456826 -0.001628 -0.126707        0
# 1     -0.346065 -0.347553  0.011748 -0.019703        0
# 2     -0.679869 -0.557805 -0.060786 -0.184415        0
# 3     -0.305198 -0.315638 -0.069763  0.120475        0
# 4      0.209230 -0.096465  0.264593  0.050267        0
# ...         ...       ...       ...       ...      ...
# 23041 -1.702067 -0.528073 -0.526839  0.592081        3
# 23042 -2.785450  1.198830 -0.662810  0.450687        3
# 23043 -2.567795  1.313459 -0.577759 -0.413684        3
# 23044 -2.362630 -0.696386 -0.454437 -0.175155        3
# 23045 -1.862521 -0.730345 -0.934917 -0.187258        3
#
# [23046 rows x 5 columns]

# %%
ls_to_append=[]
for index, row in data.iterrows():
    ls_to_append.append(row["sub_region_1"])

# ls_to_append

# %%
series_to_add_to_pca_data=pd.Series(ls_to_append)
pca_data["State"]=series_to_add_to_pca_data
pca_data
# Out:
#            PC 1      PC 2      PC 3      PC 4  Cluster    State
# 0     -0.579347 -0.456826 -0.001628 -0.126707        0  Alabama
# 1     -0.346065 -0.347553  0.011748 -0.019703        0  Alabama
# 2     -0.679869 -0.557805 -0.060786 -0.184415        0  Alabama
# 3     -0.305198 -0.315638 -0.069763  0.120475        0  Alabama
# 4      0.209230 -0.096465  0.264593  0.050267        0  Alabama
# ...         ...       ...       ...       ...      ...      ...
# 23041 -1.702067 -0.528073 -0.526839  0.592081        3  Wyoming
# 23042 -2.785450  1.198830 -0.662810  0.450687        3  Wyoming
# 23043 -2.567795  1.313459 -0.577759 -0.413684        3  Wyoming
# 23044 -2.362630 -0.696386 -0.454437 -0.175155        3  Wyoming
# 23045 -1.862521 -0.730345 -0.934917 -0.187258        3  Wyoming
#
# [23046 rows x 6 columns]

# %%
pca_data.Cluster.unique()
# Out:
# array([0, 1, 3, 2], dtype=int32)

# %%
c0={}
c1={}
c2={}
c3={}
c4={}
list_of_clusters=[c0,c1,c2,c3,c4]
for index, row in pca_data.iterrows():
    for i in range(0,5):
        if row["Cluster"]==i:
            if row["State"] in list_of_clusters[i]:
                list_of_clusters[i][row["State"]]+=1
            else:
                list_of_clusters[i][row["State"]]=1
                
                
print(list_of_clusters)
# Out:
# [{'Alabama': 213, 'Alaska': 28, 'Arizona': 71, 'Arkansas': 130, 'California': 350, 'Colorado': 153, 'Connecticut': 92, 'Delaware': 38, 'Florida': 273, 'Georgia': 382, 'Idaho': 29, 'Illinois': 346, 'Indiana': 288, 'Iowa': 119, 'Kansas': 125, 'Kentucky': 267, 'Louisiana': 266, 'Maine': 80, 'Maryland': 91, 'Massachusetts': 104, 'Michigan': 230, 'Minnesota': 169, 'Mississippi': 164, 'Missouri': 183, 'Montana': 22, 'Nebraska': 87, 'Nevada': 31, 'New Hampshire': 102, 'New Jersey': 109, 'New Mexico': 148, 'New York': 301, 'North Carolina': 452, 'North Dakota': 44, 'Ohio': 363, 'Oklahoma': 110, 'Oregon': 134, 'Pennsylvania': 365, 'Rhode Island': 54, 'South Carolina': 303, 'South Dakota': 13, 'Tennessee': 278, 'Texas': 812, 'Utah': 94, 'Vermont': 56, 'Virginia': 342, 'Washington': 268, 'West Virginia': 86, 'Wisconsin': 238, 'Wyoming': 4}, {'Alabama': 53, 'Alaska': 11, 'Arizona': 46, 'Arkansas': 31, 'California': 273, 'Colorado': 74, 'Connecticut': 46, 'Delaware': 17, 'District of Columbia': 3, 'Florida': 329, 'Georgia': 121, 'Hawaii': 5, 'Idaho': 12, 'Illinois': 117, 'Indiana': 39, 'Iowa': 17, 'Kansas': 35, 'Kentucky': 44, 'Louisiana': 69, 'Maine': 20, 'Maryland': 82, 'Massachusetts': 74, 'Michigan': 73, 'Minnesota': 49, 'Mississippi': 24, 'Missouri': 52, 'Montana': 16, 'Nebraska': 25, 'Nevada': 22, 'New Hampshire': 24, 'New Jersey': 125, 'New Mexico': 70, 'New York': 185, 'North Carolina': 126, 'North Dakota': 28, 'Ohio': 74, 'Oklahoma': 17, 'Oregon': 63, 'Pennsylvania': 151, 'Rhode Island': 24, 'South Carolina': 60, 'South Dakota': 4, 'Tennessee': 69, 'Texas': 268, 'Utah': 29, 'Vermont': 16, 'Virginia': 141, 'Washington': 91, 'West Virginia': 9, 'Wisconsin': 39, 'Wyoming': 3}, {'Alabama': 12, 'Arizona': 116, 'Arkansas': 11, 'California': 501, 'Colorado': 93, 'Connecticut': 62, 'Delaware': 24, 'District of Columbia': 27, 'Florida': 366, 'Georgia': 123, 'Hawaii': 137, 'Illinois': 115, 'Indiana': 26, 'Iowa': 10, 'Kansas': 8, 'Louisiana': 71, 'Maine': 11, 'Maryland': 193, 'Massachusetts': 175, 'Michigan': 110, 'Minnesota': 60, 'Mississippi': 5, 'Missouri': 45, 'Nebraska': 6, 'Nevada': 37, 'New Hampshire': 3, 'New Jersey': 323, 'New Mexico': 38, 'New York': 386, 'North Carolina': 100, 'Ohio': 23, 'Oregon': 75, 'Pennsylvania': 214, 'Rhode Island': 34, 'South Carolina': 4, 'Tennessee': 33, 'Texas': 334, 'Utah': 21, 'Vermont': 43, 'Virginia': 251, 'Washington': 94, 'West Virginia': 2, 'Wisconsin': 34}, {'Alabama': 202, 'Alaska': 50, 'Arizona': 110, 'Arkansas': 182, 'California': 84, 'Colorado': 86, 'Connecticut': 6, 'Delaware': 33, 'Florida': 124, 'Georgia': 170, 'Idaho': 132, 'Illinois': 144, 'Indiana': 453, 'Iowa': 142, 'Kansas': 121, 'Kentucky': 103, 'Louisiana': 168, 'Maine': 35, 'Maryland': 11, 'Massachusetts': 26, 'Michigan': 155, 'Minnesota': 35, 'Mississippi': 119, 'Missouri': 243, 'Montana': 142, 'Nebraska': 82, 'Nevada': 42, 'New Hampshire': 9, 'New Jersey': 9, 'New Mexico': 38, 'New York': 64, 'North Carolina': 170, 'North Dakota': 72, 'Ohio': 540, 'Oklahoma': 252, 'Oregon': 169, 'Pennsylvania': 195, 'Rhode Island': 8, 'South Carolina': 178, 'South Dakota': 72, 'Tennessee': 340, 'Texas': 270, 'Utah': 132, 'Virginia': 89, 'Washington': 133, 'West Virginia': 82, 'Wisconsin': 162, 'Wyoming': 104}, {}]

# %%
states_clusters={}
for index, row in pca_data.iterrows():
    if row["State"] not in states_clusters:
        state_dict={}
        for i in range(0,5):
            if row["State"] in list_of_clusters[i]:
                state_dict[i]=list_of_clusters[i][row["State"]]
        print(state_dict)
        state_dict_vals=list(state_dict.values())
        state_dict_keys=list(state_dict.keys())
        state_vals_max=max(state_dict_vals)
        max_ind=state_dict_vals.index(state_vals_max)
        max_cluster=state_dict_keys[max_ind]
        states_clusters[row["State"]]=max_cluster
print(states_clusters)
# Out:
# {0: 213, 1: 53, 2: 12, 3: 202}
# {0: 28, 1: 11, 3: 50}
# {0: 71, 1: 46, 2: 116, 3: 110}
# {0: 130, 1: 31, 2: 11, 3: 182}
# {0: 350, 1: 273, 2: 501, 3: 84}
# {0: 153, 1: 74, 2: 93, 3: 86}
# {0: 92, 1: 46, 2: 62, 3: 6}
# {0: 38, 1: 17, 2: 24, 3: 33}
# {1: 3, 2: 27}
# {0: 273, 1: 329, 2: 366, 3: 124}
# {0: 382, 1: 121, 2: 123, 3: 170}
# {1: 5, 2: 137}
# {0: 29, 1: 12, 3: 132}
# {0: 346, 1: 117, 2: 115, 3: 144}
# {0: 288, 1: 39, 2: 26, 3: 453}
# {0: 119, 1: 17, 2: 10, 3: 142}
# {0: 125, 1: 35, 2: 8, 3: 121}
# {0: 267, 1: 44, 3: 103}
# {0: 266, 1: 69, 2: 71, 3: 168}
# {0: 80, 1: 20, 2: 11, 3: 35}
# {0: 91, 1: 82, 2: 193, 3: 11}
# {0: 104, 1: 74, 2: 175, 3: 26}
# {0: 230, 1: 73, 2: 110, 3: 155}
# {0: 169, 1: 49, 2: 60, 3: 35}
# {0: 164, 1: 24, 2: 5, 3: 119}
# {0: 183, 1: 52, 2: 45, 3: 243}
# {0: 22, 1: 16, 3: 142}
# {0: 87, 1: 25, 2: 6, 3: 82}
# {0: 31, 1: 22, 2: 37, 3: 42}
# {0: 102, 1: 24, 2: 3, 3: 9}
# {0: 109, 1: 125, 2: 323, 3: 9}
# {0: 148, 1: 70, 2: 38, 3: 38}
# {0: 301, 1: 185, 2: 386, 3: 64}
# {0: 452, 1: 126, 2: 100, 3: 170}
# {0: 44, 1: 28, 3: 72}
# {0: 363, 1: 74, 2: 23, 3: 540}
# {0: 110, 1: 17, 3: 252}
# {0: 134, 1: 63, 2: 75, 3: 169}
# {0: 365, 1: 151, 2: 214, 3: 195}
# {0: 54, 1: 24, 2: 34, 3: 8}
# {0: 303, 1: 60, 2: 4, 3: 178}
# {0: 13, 1: 4, 3: 72}
# {0: 278, 1: 69, 2: 33, 3: 340}
# {0: 812, 1: 268, 2: 334, 3: 270}
# {0: 94, 1: 29, 2: 21, 3: 132}
# {0: 56, 1: 16, 2: 43}
# {0: 342, 1: 141, 2: 251, 3: 89}
# {0: 268, 1: 91, 2: 94, 3: 133}
# {0: 86, 1: 9, 2: 2, 3: 82}
# {0: 238, 1: 39, 2: 34, 3: 162}
# {0: 4, 1: 3, 3: 104}
# {'Alabama': 0, 'Alaska': 3, 'Arizona': 2, 'Arkansas': 3, 'California': 2, 'Colorado': 0, 'Connecticut': 0, 'Delaware': 0, 'District of Columbia': 2, 'Florida': 2, 'Georgia': 0, 'Hawaii': 2, 'Idaho': 3, 'Illinois': 0, 'Indiana': 3, 'Iowa': 3, 'Kansas': 0, 'Kentucky': 0, 'Louisiana': 0, 'Maine': 0, 'Maryland': 2, 'Massachusetts': 2, 'Michigan': 0, 'Minnesota': 0, 'Mississippi': 0, 'Missouri': 3, 'Montana': 3, 'Nebraska': 0, 'Nevada': 3, 'New Hampshire': 0, 'New Jersey': 2, 'New Mexico': 0, 'New York': 2, 'North Carolina': 0, 'North Dakota': 3, 'Ohio': 3, 'Oklahoma': 3, 'Oregon': 3, 'Pennsylvania': 0, 'Rhode Island': 0, 'South Carolina': 0, 'South Dakota': 3, 'Tennessee': 3, 'Texas': 0, 'Utah': 3, 'Vermont': 0, 'Virginia': 0, 'Washington': 0, 'West Virginia': 0, 'Wisconsin': 0, 'Wyoming': 3}

# %%
clusters_and_their_states={1:[], 2:[], 3:[], 4:[], 0:[]}

for i in states_clusters.keys():
    for j in range(0,5):
        if states_clusters[i]==j:
            clusters_and_their_states[j].append(i)


print(clusters_and_their_states)
# Out:
# {1: [], 2: ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'New Jersey', 'New York'], 3: ['Alaska', 'Arkansas', 'Idaho', 'Indiana', 'Iowa', 'Missouri', 'Montana', 'Nevada', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'South Dakota', 'Tennessee', 'Utah', 'Wyoming'], 4: [], 0: ['Alabama', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Michigan', 'Minnesota', 'Mississippi', 'Nebraska', 'New Hampshire', 'New Mexico', 'North Carolina', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']}

# %%
# 4d plot for april kmeans
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = pca_data["PC 1"]
y = pca_data["PC 2"]
z = pca_data["PC 3"]
z = pca_data["PC 4"]

categories = np.unique(pca_data["Cluster"])
colors = np.linspace(0, 1, len(categories))
colordict = dict(zip(categories, colors))  
pca_data["Color"] = pca_data["Cluster"].apply(lambda x: colordict[x])

img=ax.scatter(x,y,z, c=pca_data.Color)


# fig.colorbar(img)
plt.show()

# %%
num=0
pca_2=pd.DataFrame(columns=['PC 1', 'PC 2', "PC 3", "PC 4", "Cluster", "State"])
for index, row in pca_data.iterrows():
    if num%15==0:
        pca_2=pca_2.append({"PC 1": row["PC 1"],"PC 2": row["PC 2"],"PC 3": row["PC 3"],"PC 4": row["PC 4"],"Cluster": row["Cluster"],"State": row["State"] }, ignore_index=True)
    num+=1
pca_2.head
# Out:
# <bound method NDFrame.head of           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.579347 -0.456826 -0.001628 -0.126707       0  Alabama
# 1    -0.532059 -0.218846  0.129173 -0.100384       0  Alabama
# 2    -2.399165 -0.986574 -0.847107 -0.202800       3  Alabama
# 3    -2.646432 -0.958444 -0.492261 -0.159334       3  Alabama
# 4    -0.721767 -0.898684 -0.767286 -1.137874       0  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1532 -1.487469  0.255996  0.334708 -0.241212       3  Wyoming
# 1533 -1.156473 -0.652827  0.008721  0.129081       3  Wyoming
# 1534 -1.388853 -0.683744  0.208755  0.502221       3  Wyoming
# 1535 -1.111165 -0.384066 -0.386729 -0.581976       3  Wyoming
# 1536 -1.516771 -0.575209 -0.249216 -0.048154       3  Wyoming
#
# [1537 rows x 6 columns]>

# %%
pca_2
# Out:
#           PC 1      PC 2      PC 3      PC 4 Cluster    State
# 0    -0.579347 -0.456826 -0.001628 -0.126707       0  Alabama
# 1    -0.532059 -0.218846  0.129173 -0.100384       0  Alabama
# 2    -2.399165 -0.986574 -0.847107 -0.202800       3  Alabama
# 3    -2.646432 -0.958444 -0.492261 -0.159334       3  Alabama
# 4    -0.721767 -0.898684 -0.767286 -1.137874       0  Alabama
# ...        ...       ...       ...       ...     ...      ...
# 1532 -1.487469  0.255996  0.334708 -0.241212       3  Wyoming
# 1533 -1.156473 -0.652827  0.008721  0.129081       3  Wyoming
# 1534 -1.388853 -0.683744  0.208755  0.502221       3  Wyoming
# 1535 -1.111165 -0.384066 -0.386729 -0.581976       3  Wyoming
# 1536 -1.516771 -0.575209 -0.249216 -0.048154       3  Wyoming
#
# [1537 rows x 6 columns]

# %%
clusters_and_their_states.values()
# Out:
# dict_values([[], ['Arizona', 'California', 'District of Columbia', 'Florida', 'Hawaii', 'Maryland', 'Massachusetts', 'New Jersey', 'New York'], ['Alaska', 'Arkansas', 'Idaho', 'Indiana', 'Iowa', 'Missouri', 'Montana', 'Nevada', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'South Dakota', 'Tennessee', 'Utah', 'Wyoming'], [], ['Alabama', 'Colorado', 'Connecticut', 'Delaware', 'Georgia', 'Illinois', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Michigan', 'Minnesota', 'Mississippi', 'Nebraska', 'New Hampshire', 'New Mexico', 'North Carolina', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Texas', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin']])

# %%
# vals=list(clusters_and_their_states.values())
# keys=list(clusters_and_their_states.keys())
# for index, row in pca_2.iterrows():
#     for i in range(len(vals)):
#         if row["State"] in vals[i]:
#             pca_2.at[index, "Cluster"]= keys[i]
# pca_2

# %%
# 5d plot for  kmeans




import plotly
import plotly.graph_objs as go

#Set marker properties
markercolor = pca_2["Cluster"]
markersize = (pca_2['PC 4']+6)*2

#Make Plotly figure
fig1 = go.Scatter3d(x=pca_2["PC 1"],
                    y=pca_2["PC 2"],
                    z=pca_2["PC 3"],
                    marker=dict(size=markersize,
                                color=markercolor,
                                opacity=0.9,
                                reversescale=True,colorscale='Rainbow'),
                    line=dict (width=0.02),
                    mode='markers')

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title="Principal Component 1"),
                                yaxis=dict( title="Principal Component 2"),
                                zaxis=dict(title="Principal Component 3")),
                    )

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True, filename=("JUNE Mobility KMeans.html")
                   )
# Out:
# 'JUNE Mobility KMeans.html'
